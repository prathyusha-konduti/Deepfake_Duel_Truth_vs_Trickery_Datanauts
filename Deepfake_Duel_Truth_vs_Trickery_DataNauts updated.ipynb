# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
#  ArtiFact_240K.zip
#  best_model_mobilenet.h5
# 'Colab Notebooks'
# 'Deepfake Duel: Truth vs. Trickery.ipynb'
#  deepfake_mobile_model.h5
# 'Getting started.pdf'
# 'Ravi kumar & Uva lakshmi Wedding.mp4'
#  Untitled
#  Untitled0.ipynb
# 'Untitled (1)'
#  Untitled1.ipynb
# 'www.TamilRockers.lu - O Kadhal Kanmani (2015) Tamil Itunes Untouched 1080p HD AVC x264 DD 5.1 & 2.0 - 4.9GB.m4v'

# %%
# !unzip "/content/drive/MyDrive/ArtiFact_240K.zip" -d /content/ArtiFact_240K
# Out:
# Archive:  /content/drive/MyDrive/ArtiFact_240K.zip
# replace /content/ArtiFact_240K/ArtiFact_240K/metadata.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !pip install tensorflow pandas matplotlib --quiet

# %%
import os
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from tensorflow.keras.utils import Sequence
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
class DeepfakeDataGenerator(Sequence):
    def __init__(self, base_dir, batch_size=32, img_size=(299, 299), shuffle=True):
        self.img_size = img_size
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.filepaths, self.labels, self.classes = self._load_data(base_dir)
        self.indexes = np.arange(len(self.filepaths))
        self.class_to_index = {'human_faces': 0, 'animals': 1, 'vehicles': 2}

    def _load_data(self, base_dir):
        filepaths, labels, classes = [], [], []
        for label_dir in ['real', 'fake']:
            label_val = 1 if label_dir == 'real' else 0
            for class_dir in ['human_faces', 'animals', 'vehicles']:
                path = os.path.join(base_dir, label_dir, class_dir)
                if os.path.exists(path):
                    for fname in os.listdir(path):
                        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                            filepaths.append(os.path.join(path, fname))
                            labels.append(label_val)
                            classes.append(class_dir)
        return filepaths, labels, classes

    def __len__(self):
        return len(self.filepaths) // self.batch_size

    def on_epoch_end(self):
        if self.shuffle:
            temp = list(zip(self.filepaths, self.labels, self.classes))
            random.shuffle(temp)
            self.filepaths, self.labels, self.classes = zip(*temp)

    def __getitem__(self, idx):
        batch_files = self.filepaths[idx*self.batch_size:(idx+1)*self.batch_size]
        batch_labels = self.labels[idx*self.batch_size:(idx+1)*self.batch_size]
        batch_classes = self.classes[idx*self.batch_size:(idx+1)*self.batch_size]

        X = np.zeros((self.batch_size, *self.img_size, 3), dtype='float32')
        y_label = np.zeros((self.batch_size, 1), dtype='float32')
        y_class = np.zeros((self.batch_size, 3), dtype='float32')

        for i, filepath in enumerate(batch_files):
            img = load_img(filepath, target_size=self.img_size)
            img = img_to_array(img) / 255.0
            X[i] = img
            y_label[i] = batch_labels[i]
            y_class[i, self.class_to_index[batch_classes[i]]] = 1

        return X, {'label_output': y_label, 'class_output': y_class}

# %%
input_tensor = Input(shape=(299, 299, 3))
base_model = Xception(include_top=False, weights='imagenet', input_tensor=input_tensor)

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(128, activation='relu')(x)

label_output = Dense(1, activation='sigmoid', name='label_output')(x)
class_output = Dense(3, activation='softmax', name='class_output')(x)

model = Model(inputs=input_tensor, outputs=[label_output, class_output])

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss={'label_output': 'binary_crossentropy', 'class_output': 'categorical_crossentropy'},
    metrics={'label_output': 'accuracy', 'class_output': 'accuracy'}
)

# %%
model.save("deepfake_detector_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
train_dir = "/content/ArtiFact_240K/ArtiFact_240K/train"
val_dir = "/content/ArtiFact_240K/ArtiFact_240K/validation"

# Use a smaller subset for fast testing
train_gen = DeepfakeDataGenerator(train_dir, batch_size=32)
val_gen = DeepfakeDataGenerator(val_dir, batch_size=32)

# Only use part of the dataset
train_gen.filepaths = train_gen.filepaths[:3000]
val_gen.filepaths = val_gen.filepaths[:600]

# %%
history = model.fit(
    train_gen,
    validation_data=val_gen,
    steps_per_epoch=100,
    validation_steps=20,
    epochs=5
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  93/100 ━━━━━━━━━━━━━━━━━━━━ 6s 908ms/step - class_output_accuracy: 0.9948 - class_output_loss: 0.1711 - label_output_accuracy: 0.9948 - label_output_loss: 0.1508 - loss: 0.3219
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 173s 928ms/step - class_output_accuracy: 0.9951 - class_output_loss: 0.1626 - label_output_accuracy: 0.9951 - label_output_loss: 0.1437 - loss: 0.3063 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 2.1178e-04 - val_label_output_accuracy: 1.0000 - val_label_output_loss: 2.9569e-04 - val_loss: 5.0747e-04
# Epoch 2/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 146s 905ms/step - class_output_accuracy: 1.0000 - class_output_loss: 6.1000e-04 - label_output_accuracy: 1.0000 - label_output_loss: 7.3607e-04 - loss: 0.0013 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 1.6060e-04 - val_label_output_accuracy: 1.0000 - val_label_output_loss: 2.2465e-04 - val_loss: 3.8526e-04
# Epoch 3/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 90s 898ms/step - class_output_accuracy: 1.0000 - class_output_loss: 2.8108e-04 - label_output_accuracy: 1.0000 - label_output_loss: 3.5465e-04 - loss: 6.3572e-04 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 1.3278e-04 - val_label_output_accuracy: 1.0000 - val_label_output_loss: 1.7767e-04 - val_loss: 3.1045e-04
# Epoch 4/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 143s 909ms/step - class_output_accuracy: 1.0000 - class_output_loss: 1.6402e-04 - label_output_accuracy: 1.0000 - label_output_loss: 2.1235e-04 - loss: 3.7636e-04 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 1.0552e-04 - val_label_output_accuracy: 1.0000 - val_label_output_loss: 1.3982e-04 - val_loss: 2.4534e-04
# Epoch 5/5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 142s 909ms/step - class_output_accuracy: 1.0000 - class_output_loss: 1.0551e-04 - label_output_accuracy: 1.0000 - label_output_loss: 1.3975e-04 - loss: 2.4525e-04 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 7.9861e-05 - val_label_output_accuracy: 1.0000 - val_label_output_loss: 1.0701e-04 - val_loss: 1.8688e-04

# %%
model.save("deepfake_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Load model (make sure you point to the correct model path if needed)
model = load_model("deepfake_model.h5")

# Set test folder path
test_dir = "/content/ArtiFact_240K/ArtiFact_240K/test"
class_names = ['human_faces', 'animals', 'vehicles']

# Create result list
results = []
image_count = 0

# Loop through test images
for fname in sorted(os.listdir(test_dir)):
    if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_count += 1
        img_path = os.path.join(test_dir, fname)

        # Load and preprocess image
        img = load_img(img_path, target_size=(299, 299))  # Adjust if using MobileNetV2 to (224, 224)
        img_arr = img_to_array(img) / 255.0
        img_arr = np.expand_dims(img_arr, axis=0)

        # Predict
        label_pred, class_pred = model.predict(img_arr, verbose=0)
        label = int(label_pred[0][0] > 0.5)
        class_idx = np.argmax(class_pred[0])
        class_name = class_names[class_idx]

        results.append([fname, label, class_name])
        print(f"[{image_count}] {fname} → Label: {'Real' if label else 'Fake'}, Class: {class_name}")

# Save results
df = pd.DataFrame(results, columns=["image", "label", "class"])
df.to_csv("test.csv", index=False)

# Summary output
print(f"\n✅ Done! Total images tested: {image_count}")
print("📄 test.csv saved.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Streaming output truncated to the last 5000 lines.
# [7006] test_07006.jpg → Label: Real, Class: human_faces
# [7007] test_07007.jpg → Label: Real, Class: human_faces
# [7008] test_07008.jpg → Label: Real, Class: human_faces
# [7009] test_07009.jpg → Label: Real, Class: human_faces
# [7010] test_07010.jpg → Label: Real, Class: human_faces
# [7011] test_07011.jpg → Label: Real, Class: human_faces
# [7012] test_07012.jpg → Label: Real, Class: human_faces
# [7013] test_07013.jpg → Label: Real, Class: human_faces
# [7014] test_07014.jpg → Label: Real, Class: human_faces
# [7015] test_07015.jpg → Label: Real, Class: human_faces
# [7016] test_07016.jpg → Label: Real, Class: human_faces
# [7017] test_07017.jpg → Label: Real, Class: human_faces
# [7018] test_07018.jpg → Label: Real, Class: human_faces
# [7019] test_07019.jpg → Label: Real, Class: human_faces
# [7020] test_07020.jpg → Label: Real, Class: human_faces
# [7021] test_07021.jpg → Label: Real, Class: human_faces
# [7022] test_07022.jpg → Label: Real, Class: human_faces
# [7023] test_07023.jpg → Label: Real, Class: human_faces
# [7024] test_07024.jpg → Label: Real, Class: human_faces
# [7025] test_07025.jpg → Label: Real, Class: human_faces
# [7026] test_07026.jpg → Label: Real, Class: human_faces
# [7027] test_07027.jpg → Label: Real, Class: human_faces
# [7028] test_07028.jpg → Label: Real, Class: human_faces
# [7029] test_07029.jpg → Label: Real, Class: human_faces
# [7030] test_07030.jpg → Label: Real, Class: human_faces
# [7031] test_07031.jpg → Label: Real, Class: human_faces
# [7032] test_07032.jpg → Label: Real, Class: human_faces
# [7033] test_07033.jpg → Label: Real, Class: human_faces
# [7034] test_07034.jpg → Label: Real, Class: human_faces
# [7035] test_07035.jpg → Label: Real, Class: human_faces
# [7036] test_07036.jpg → Label: Real, Class: human_faces
# [7037] test_07037.jpg → Label: Real, Class: human_faces
# [7038] test_07038.jpg → Label: Real, Class: human_faces
# [7039] test_07039.jpg → Label: Real, Class: human_faces
# [7040] test_07040.jpg → Label: Real, Class: human_faces
# [7041] test_07041.jpg → Label: Real, Class: human_faces
# [7042] test_07042.jpg → Label: Real, Class: human_faces
# [7043] test_07043.jpg → Label: Real, Class: human_faces
# [7044] test_07044.jpg → Label: Real, Class: human_faces
# [7045] test_07045.jpg → Label: Real, Class: human_faces
# [7046] test_07046.jpg → Label: Real, Class: human_faces
# [7047] test_07047.jpg → Label: Real, Class: human_faces
# [7048] test_07048.jpg → Label: Real, Class: human_faces
# [7049] test_07049.jpg → Label: Real, Class: human_faces
# [7050] test_07050.jpg → Label: Real, Class: human_faces
# [7051] test_07051.jpg → Label: Real, Class: human_faces
# [7052] test_07052.jpg → Label: Real, Class: human_faces
# [7053] test_07053.jpg → Label: Real, Class: human_faces
# [7054] test_07054.jpg → Label: Real, Class: human_faces
# [7055] test_07055.jpg → Label: Real, Class: human_faces
# [7056] test_07056.jpg → Label: Real, Class: human_faces
# [7057] test_07057.jpg → Label: Real, Class: human_faces
# [7058] test_07058.jpg → Label: Real, Class: human_faces
# [7059] test_07059.jpg → Label: Real, Class: human_faces
# [7060] test_07060.jpg → Label: Real, Class: human_faces
# [7061] test_07061.jpg → Label: Real, Class: human_faces
# [7062] test_07062.jpg → Label: Real, Class: human_faces
# [7063] test_07063.jpg → Label: Real, Class: human_faces
# [7064] test_07064.jpg → Label: Real, Class: human_faces
# [7065] test_07065.jpg → Label: Real, Class: human_faces
# [7066] test_07066.jpg → Label: Real, Class: human_faces
# [7067] test_07067.jpg → Label: Real, Class: human_faces
# [7068] test_07068.jpg → Label: Real, Class: human_faces
# [7069] test_07069.jpg → Label: Real, Class: human_faces
# [7070] test_07070.jpg → Label: Real, Class: human_faces
# [7071] test_07071.jpg → Label: Real, Class: human_faces
# [7072] test_07072.jpg → Label: Real, Class: human_faces
# [7073] test_07073.jpg → Label: Real, Class: human_faces
# [7074] test_07074.jpg → Label: Real, Class: human_faces
# [7075] test_07075.jpg → Label: Real, Class: human_faces
# [7076] test_07076.jpg → Label: Real, Class: human_faces
# [7077] test_07077.jpg → Label: Real, Class: human_faces
# [7078] test_07078.jpg → Label: Real, Class: human_faces
# [7079] test_07079.jpg → Label: Real, Class: human_faces
# [7080] test_07080.jpg → Label: Real, Class: human_faces
# [7081] test_07081.jpg → Label: Real, Class: human_faces
# [7082] test_07082.jpg → Label: Real, Class: human_faces
# [7083] test_07083.jpg → Label: Real, Class: human_faces
# [7084] test_07084.jpg → Label: Real, Class: human_faces
# [7085] test_07085.jpg → Label: Real, Class: human_faces
# [7086] test_07086.jpg → Label: Real, Class: human_faces
# [7087] test_07087.jpg → Label: Real, Class: human_faces
# [7088] test_07088.jpg → Label: Real, Class: human_faces
# [7089] test_07089.jpg → Label: Real, Class: human_faces
# [7090] test_07090.jpg → Label: Real, Class: human_faces
# [7091] test_07091.jpg → Label: Real, Class: human_faces
# [7092] test_07092.jpg → Label: Real, Class: human_faces
# [7093] test_07093.jpg → Label: Real, Class: human_faces
# [7094] test_07094.jpg → Label: Real, Class: human_faces
# [7095] test_07095.jpg → Label: Real, Class: human_faces
# [7096] test_07096.jpg → Label: Real, Class: human_faces
# [7097] test_07097.jpg → Label: Real, Class: human_faces
# [7098] test_07098.jpg → Label: Real, Class: human_faces
# [7099] test_07099.jpg → Label: Real, Class: human_faces
# [7100] test_07100.jpg → Label: Real, Class: human_faces
# [7101] test_07101.jpg → Label: Real, Class: human_faces
# [7102] test_07102.jpg → Label: Real, Class: human_faces
# [7103] test_07103.jpg → Label: Real, Class: human_faces
# [7104] test_07104.jpg → Label: Real, Class: human_faces
# [7105] test_07105.jpg → Label: Real, Class: human_faces
# [7106] test_07106.jpg → Label: Real, Class: human_faces
# [7107] test_07107.jpg → Label: Real, Class: human_faces
# [7108] test_07108.jpg → Label: Real, Class: human_faces
# [7109] test_07109.jpg → Label: Real, Class: human_faces
# [7110] test_07110.jpg → Label: Real, Class: human_faces
# [7111] test_07111.jpg → Label: Real, Class: human_faces
# [7112] test_07112.jpg → Label: Real, Class: human_faces
# [7113] test_07113.jpg → Label: Real, Class: human_faces
# [7114] test_07114.jpg → Label: Real, Class: human_faces
# [7115] test_07115.jpg → Label: Real, Class: human_faces
# [7116] test_07116.jpg → Label: Real, Class: human_faces
# [7117] test_07117.jpg → Label: Real, Class: human_faces
# [7118] test_07118.jpg → Label: Real, Class: human_faces
# [7119] test_07119.jpg → Label: Real, Class: human_faces
# [7120] test_07120.jpg → Label: Real, Class: human_faces
# [7121] test_07121.jpg → Label: Real, Class: human_faces
# [7122] test_07122.jpg → Label: Real, Class: human_faces
# [7123] test_07123.jpg → Label: Real, Class: human_faces
# [7124] test_07124.jpg → Label: Real, Class: human_faces
# [7125] test_07125.jpg → Label: Real, Class: human_faces
# [7126] test_07126.jpg → Label: Real, Class: human_faces
# [7127] test_07127.jpg → Label: Real, Class: human_faces
# [7128] test_07128.jpg → Label: Real, Class: human_faces
# [7129] test_07129.jpg → Label: Real, Class: human_faces
# [7130] test_07130.jpg → Label: Real, Class: human_faces
# [7131] test_07131.jpg → Label: Real, Class: human_faces
# [7132] test_07132.jpg → Label: Real, Class: human_faces
# [7133] test_07133.jpg → Label: Real, Class: human_faces
# [7134] test_07134.jpg → Label: Real, Class: human_faces
# [7135] test_07135.jpg → Label: Real, Class: human_faces
# [7136] test_07136.jpg → Label: Real, Class: human_faces
# [7137] test_07137.jpg → Label: Real, Class: human_faces
# [7138] test_07138.jpg → Label: Real, Class: human_faces
# [7139] test_07139.jpg → Label: Real, Class: human_faces
# [7140] test_07140.jpg → Label: Real, Class: human_faces
# [7141] test_07141.jpg → Label: Real, Class: human_faces
# [7142] test_07142.jpg → Label: Real, Class: human_faces
# [7143] test_07143.jpg → Label: Real, Class: human_faces
# [7144] test_07144.jpg → Label: Real, Class: human_faces
# [7145] test_07145.jpg → Label: Real, Class: human_faces
# [7146] test_07146.jpg → Label: Real, Class: human_faces
# [7147] test_07147.jpg → Label: Real, Class: human_faces
# [7148] test_07148.jpg → Label: Real, Class: human_faces
# [7149] test_07149.jpg → Label: Real, Class: human_faces
# [7150] test_07150.jpg → Label: Real, Class: human_faces
# [7151] test_07151.jpg → Label: Real, Class: human_faces
# [7152] test_07152.jpg → Label: Real, Class: human_faces
# [7153] test_07153.jpg → Label: Real, Class: human_faces
# [7154] test_07154.jpg → Label: Real, Class: human_faces
# [7155] test_07155.jpg → Label: Real, Class: human_faces
# [7156] test_07156.jpg → Label: Real, Class: human_faces
# [7157] test_07157.jpg → Label: Real, Class: human_faces
# [7158] test_07158.jpg → Label: Real, Class: human_faces
# [7159] test_07159.jpg → Label: Real, Class: human_faces
# [7160] test_07160.jpg → Label: Real, Class: human_faces
# [7161] test_07161.jpg → Label: Real, Class: human_faces
# [7162] test_07162.jpg → Label: Real, Class: human_faces
# [7163] test_07163.jpg → Label: Real, Class: human_faces
# [7164] test_07164.jpg → Label: Real, Class: human_faces
# [7165] test_07165.jpg → Label: Real, Class: human_faces
# [7166] test_07166.jpg → Label: Real, Class: human_faces
# [7167] test_07167.jpg → Label: Real, Class: human_faces
# [7168] test_07168.jpg → Label: Real, Class: human_faces
# [7169] test_07169.jpg → Label: Real, Class: human_faces
# [7170] test_07170.jpg → Label: Real, Class: human_faces
# [7171] test_07171.jpg → Label: Real, Class: human_faces
# [7172] test_07172.jpg → Label: Real, Class: human_faces
# [7173] test_07173.jpg → Label: Real, Class: human_faces
# [7174] test_07174.jpg → Label: Real, Class: human_faces
# [7175] test_07175.jpg → Label: Real, Class: human_faces
# [7176] test_07176.jpg → Label: Real, Class: human_faces
# [7177] test_07177.jpg → Label: Real, Class: human_faces
# [7178] test_07178.jpg → Label: Real, Class: human_faces
# [7179] test_07179.jpg → Label: Real, Class: human_faces
# [7180] test_07180.jpg → Label: Real, Class: human_faces
# [7181] test_07181.jpg → Label: Real, Class: human_faces
# [7182] test_07182.jpg → Label: Real, Class: human_faces
# [7183] test_07183.jpg → Label: Real, Class: human_faces
# [7184] test_07184.jpg → Label: Real, Class: human_faces
# [7185] test_07185.jpg → Label: Real, Class: human_faces
# [7186] test_07186.jpg → Label: Real, Class: human_faces
# [7187] test_07187.jpg → Label: Real, Class: human_faces
# [7188] test_07188.jpg → Label: Real, Class: human_faces
# [7189] test_07189.jpg → Label: Real, Class: human_faces
# [7190] test_07190.jpg → Label: Real, Class: human_faces
# [7191] test_07191.jpg → Label: Real, Class: human_faces
# [7192] test_07192.jpg → Label: Real, Class: human_faces
# [7193] test_07193.jpg → Label: Real, Class: human_faces
# [7194] test_07194.jpg → Label: Real, Class: human_faces
# [7195] test_07195.jpg → Label: Real, Class: human_faces
# [7196] test_07196.jpg → Label: Real, Class: human_faces
# [7197] test_07197.jpg → Label: Real, Class: human_faces
# [7198] test_07198.jpg → Label: Real, Class: human_faces
# [7199] test_07199.jpg → Label: Real, Class: human_faces
# [7200] test_07200.jpg → Label: Real, Class: human_faces
# [7201] test_07201.jpg → Label: Real, Class: human_faces
# [7202] test_07202.jpg → Label: Real, Class: human_faces
# [7203] test_07203.jpg → Label: Real, Class: human_faces
# [7204] test_07204.jpg → Label: Real, Class: human_faces
# [7205] test_07205.jpg → Label: Real, Class: human_faces
# [7206] test_07206.jpg → Label: Real, Class: human_faces
# [7207] test_07207.jpg → Label: Real, Class: human_faces
# [7208] test_07208.jpg → Label: Real, Class: human_faces
# [7209] test_07209.jpg → Label: Real, Class: human_faces
# [7210] test_07210.jpg → Label: Real, Class: human_faces
# [7211] test_07211.jpg → Label: Real, Class: human_faces
# [7212] test_07212.jpg → Label: Real, Class: human_faces
# [7213] test_07213.jpg → Label: Real, Class: human_faces
# [7214] test_07214.jpg → Label: Real, Class: human_faces
# [7215] test_07215.jpg → Label: Real, Class: human_faces
# [7216] test_07216.jpg → Label: Real, Class: human_faces
# [7217] test_07217.jpg → Label: Real, Class: human_faces
# [7218] test_07218.jpg → Label: Real, Class: human_faces
# [7219] test_07219.jpg → Label: Real, Class: human_faces
# [7220] test_07220.jpg → Label: Real, Class: human_faces
# [7221] test_07221.jpg → Label: Real, Class: human_faces
# [7222] test_07222.jpg → Label: Real, Class: human_faces
# [7223] test_07223.jpg → Label: Real, Class: human_faces
# [7224] test_07224.jpg → Label: Real, Class: human_faces
# [7225] test_07225.jpg → Label: Real, Class: human_faces
# [7226] test_07226.jpg → Label: Real, Class: human_faces
# [7227] test_07227.jpg → Label: Real, Class: human_faces
# [7228] test_07228.jpg → Label: Real, Class: human_faces
# [7229] test_07229.jpg → Label: Real, Class: human_faces
# [7230] test_07230.jpg → Label: Real, Class: human_faces
# [7231] test_07231.jpg → Label: Real, Class: human_faces
# [7232] test_07232.jpg → Label: Real, Class: human_faces
# [7233] test_07233.jpg → Label: Real, Class: human_faces
# [7234] test_07234.jpg → Label: Real, Class: human_faces
# [7235] test_07235.jpg → Label: Real, Class: human_faces
# [7236] test_07236.jpg → Label: Real, Class: human_faces
# [7237] test_07237.jpg → Label: Real, Class: human_faces
# [7238] test_07238.jpg → Label: Real, Class: human_faces
# [7239] test_07239.jpg → Label: Real, Class: human_faces
# [7240] test_07240.jpg → Label: Real, Class: human_faces
# [7241] test_07241.jpg → Label: Real, Class: human_faces
# [7242] test_07242.jpg → Label: Real, Class: human_faces
# [7243] test_07243.jpg → Label: Real, Class: human_faces
# [7244] test_07244.jpg → Label: Real, Class: human_faces
# [7245] test_07245.jpg → Label: Real, Class: human_faces
# [7246] test_07246.jpg → Label: Real, Class: human_faces
# [7247] test_07247.jpg → Label: Real, Class: human_faces
# [7248] test_07248.jpg → Label: Real, Class: human_faces
# [7249] test_07249.jpg → Label: Real, Class: human_faces
# [7250] test_07250.jpg → Label: Real, Class: human_faces
# [7251] test_07251.jpg → Label: Real, Class: human_faces
# [7252] test_07252.jpg → Label: Real, Class: human_faces
# [7253] test_07253.jpg → Label: Real, Class: human_faces
# [7254] test_07254.jpg → Label: Real, Class: human_faces
# [7255] test_07255.jpg → Label: Real, Class: human_faces
# [7256] test_07256.jpg → Label: Real, Class: human_faces
# [7257] test_07257.jpg → Label: Real, Class: human_faces
# [7258] test_07258.jpg → Label: Real, Class: human_faces
# [7259] test_07259.jpg → Label: Real, Class: human_faces
# [7260] test_07260.jpg → Label: Real, Class: human_faces
# [7261] test_07261.jpg → Label: Real, Class: human_faces
# [7262] test_07262.jpg → Label: Real, Class: human_faces
# [7263] test_07263.jpg → Label: Real, Class: human_faces
# [7264] test_07264.jpg → Label: Real, Class: human_faces
# [7265] test_07265.jpg → Label: Real, Class: human_faces
# [7266] test_07266.jpg → Label: Real, Class: human_faces
# [7267] test_07267.jpg → Label: Real, Class: human_faces
# [7268] test_07268.jpg → Label: Real, Class: human_faces
# [7269] test_07269.jpg → Label: Real, Class: human_faces
# [7270] test_07270.jpg → Label: Real, Class: human_faces
# [7271] test_07271.jpg → Label: Real, Class: human_faces
# [7272] test_07272.jpg → Label: Real, Class: human_faces
# [7273] test_07273.jpg → Label: Real, Class: human_faces
# [7274] test_07274.jpg → Label: Real, Class: human_faces
# [7275] test_07275.jpg → Label: Real, Class: human_faces
# [7276] test_07276.jpg → Label: Real, Class: human_faces
# [7277] test_07277.jpg → Label: Real, Class: human_faces
# [7278] test_07278.jpg → Label: Real, Class: human_faces
# [7279] test_07279.jpg → Label: Real, Class: human_faces
# [7280] test_07280.jpg → Label: Real, Class: human_faces
# [7281] test_07281.jpg → Label: Real, Class: human_faces
# [7282] test_07282.jpg → Label: Real, Class: human_faces
# [7283] test_07283.jpg → Label: Real, Class: human_faces
# [7284] test_07284.jpg → Label: Real, Class: human_faces
# [7285] test_07285.jpg → Label: Real, Class: human_faces
# [7286] test_07286.jpg → Label: Real, Class: human_faces
# [7287] test_07287.jpg → Label: Real, Class: human_faces
# [7288] test_07288.jpg → Label: Real, Class: human_faces
# [7289] test_07289.jpg → Label: Real, Class: human_faces
# [7290] test_07290.jpg → Label: Real, Class: human_faces
# [7291] test_07291.jpg → Label: Real, Class: human_faces
# [7292] test_07292.jpg → Label: Real, Class: human_faces
# [7293] test_07293.jpg → Label: Real, Class: human_faces
# [7294] test_07294.jpg → Label: Real, Class: human_faces
# [7295] test_07295.jpg → Label: Real, Class: human_faces
# [7296] test_07296.jpg → Label: Real, Class: human_faces
# [7297] test_07297.jpg → Label: Real, Class: human_faces
# [7298] test_07298.jpg → Label: Real, Class: human_faces
# [7299] test_07299.jpg → Label: Real, Class: human_faces
# [7300] test_07300.jpg → Label: Real, Class: human_faces
# [7301] test_07301.jpg → Label: Real, Class: human_faces
# [7302] test_07302.jpg → Label: Real, Class: human_faces
# [7303] test_07303.jpg → Label: Real, Class: human_faces
# [7304] test_07304.jpg → Label: Real, Class: human_faces
# [7305] test_07305.jpg → Label: Real, Class: human_faces
# [7306] test_07306.jpg → Label: Real, Class: human_faces
# [7307] test_07307.jpg → Label: Real, Class: human_faces
# [7308] test_07308.jpg → Label: Real, Class: human_faces
# [7309] test_07309.jpg → Label: Real, Class: human_faces
# [7310] test_07310.jpg → Label: Real, Class: human_faces
# [7311] test_07311.jpg → Label: Real, Class: human_faces
# [7312] test_07312.jpg → Label: Real, Class: human_faces
# [7313] test_07313.jpg → Label: Real, Class: human_faces
# [7314] test_07314.jpg → Label: Real, Class: human_faces
# [7315] test_07315.jpg → Label: Real, Class: human_faces
# [7316] test_07316.jpg → Label: Real, Class: human_faces
# [7317] test_07317.jpg → Label: Real, Class: human_faces
# [7318] test_07318.jpg → Label: Real, Class: human_faces
# [7319] test_07319.jpg → Label: Real, Class: human_faces
# [7320] test_07320.jpg → Label: Real, Class: human_faces
# [7321] test_07321.jpg → Label: Real, Class: human_faces
# [7322] test_07322.jpg → Label: Real, Class: human_faces
# [7323] test_07323.jpg → Label: Real, Class: human_faces
# [7324] test_07324.jpg → Label: Real, Class: human_faces
# [7325] test_07325.jpg → Label: Real, Class: human_faces
# [7326] test_07326.jpg → Label: Real, Class: human_faces
# [7327] test_07327.jpg → Label: Real, Class: human_faces
# [7328] test_07328.jpg → Label: Real, Class: human_faces
# [7329] test_07329.jpg → Label: Real, Class: human_faces
# [7330] test_07330.jpg → Label: Real, Class: human_faces
# [7331] test_07331.jpg → Label: Real, Class: human_faces
# [7332] test_07332.jpg → Label: Real, Class: human_faces
# [7333] test_07333.jpg → Label: Real, Class: human_faces
# [7334] test_07334.jpg → Label: Real, Class: human_faces
# [7335] test_07335.jpg → Label: Real, Class: human_faces
# [7336] test_07336.jpg → Label: Real, Class: human_faces
# [7337] test_07337.jpg → Label: Real, Class: human_faces
# [7338] test_07338.jpg → Label: Real, Class: human_faces
# [7339] test_07339.jpg → Label: Real, Class: human_faces
# [7340] test_07340.jpg → Label: Real, Class: human_faces
# [7341] test_07341.jpg → Label: Real, Class: human_faces
# [7342] test_07342.jpg → Label: Real, Class: human_faces
# [7343] test_07343.jpg → Label: Real, Class: human_faces
# [7344] test_07344.jpg → Label: Real, Class: human_faces
# [7345] test_07345.jpg → Label: Real, Class: human_faces
# [7346] test_07346.jpg → Label: Real, Class: human_faces
# [7347] test_07347.jpg → Label: Real, Class: human_faces
# [7348] test_07348.jpg → Label: Real, Class: human_faces
# [7349] test_07349.jpg → Label: Real, Class: human_faces
# [7350] test_07350.jpg → Label: Real, Class: human_faces
# [7351] test_07351.jpg → Label: Real, Class: human_faces
# [7352] test_07352.jpg → Label: Real, Class: human_faces
# [7353] test_07353.jpg → Label: Real, Class: human_faces
# [7354] test_07354.jpg → Label: Real, Class: human_faces
# [7355] test_07355.jpg → Label: Real, Class: human_faces
# [7356] test_07356.jpg → Label: Real, Class: human_faces
# [7357] test_07357.jpg → Label: Real, Class: human_faces
# [7358] test_07358.jpg → Label: Real, Class: human_faces
# [7359] test_07359.jpg → Label: Real, Class: human_faces
# [7360] test_07360.jpg → Label: Real, Class: human_faces
# [7361] test_07361.jpg → Label: Real, Class: human_faces
# [7362] test_07362.jpg → Label: Real, Class: human_faces
# [7363] test_07363.jpg → Label: Real, Class: human_faces
# [7364] test_07364.jpg → Label: Real, Class: human_faces
# [7365] test_07365.jpg → Label: Real, Class: human_faces
# [7366] test_07366.jpg → Label: Real, Class: human_faces
# [7367] test_07367.jpg → Label: Real, Class: human_faces
# [7368] test_07368.jpg → Label: Real, Class: human_faces
# [7369] test_07369.jpg → Label: Real, Class: human_faces
# [7370] test_07370.jpg → Label: Real, Class: human_faces
# [7371] test_07371.jpg → Label: Real, Class: human_faces
# [7372] test_07372.jpg → Label: Real, Class: human_faces
# [7373] test_07373.jpg → Label: Real, Class: human_faces
# [7374] test_07374.jpg → Label: Real, Class: human_faces
# [7375] test_07375.jpg → Label: Real, Class: human_faces
# [7376] test_07376.jpg → Label: Real, Class: human_faces
# [7377] test_07377.jpg → Label: Real, Class: human_faces
# [7378] test_07378.jpg → Label: Real, Class: human_faces
# [7379] test_07379.jpg → Label: Real, Class: human_faces
# [7380] test_07380.jpg → Label: Real, Class: human_faces
# [7381] test_07381.jpg → Label: Real, Class: human_faces
# [7382] test_07382.jpg → Label: Real, Class: human_faces
# [7383] test_07383.jpg → Label: Real, Class: human_faces
# [7384] test_07384.jpg → Label: Real, Class: human_faces
# [7385] test_07385.jpg → Label: Real, Class: human_faces
# [7386] test_07386.jpg → Label: Real, Class: human_faces
# [7387] test_07387.jpg → Label: Real, Class: human_faces
# [7388] test_07388.jpg → Label: Real, Class: human_faces
# [7389] test_07389.jpg → Label: Real, Class: human_faces
# [7390] test_07390.jpg → Label: Real, Class: human_faces
# [7391] test_07391.jpg → Label: Real, Class: human_faces
# [7392] test_07392.jpg → Label: Real, Class: human_faces
# [7393] test_07393.jpg → Label: Real, Class: human_faces
# [7394] test_07394.jpg → Label: Real, Class: human_faces
# [7395] test_07395.jpg → Label: Real, Class: human_faces
# [7396] test_07396.jpg → Label: Real, Class: human_faces
# [7397] test_07397.jpg → Label: Real, Class: human_faces
# [7398] test_07398.jpg → Label: Real, Class: human_faces
# [7399] test_07399.jpg → Label: Real, Class: human_faces
# [7400] test_07400.jpg → Label: Real, Class: human_faces
# [7401] test_07401.jpg → Label: Real, Class: human_faces
# [7402] test_07402.jpg → Label: Real, Class: human_faces
# [7403] test_07403.jpg → Label: Real, Class: human_faces
# [7404] test_07404.jpg → Label: Real, Class: human_faces
# [7405] test_07405.jpg → Label: Real, Class: human_faces
# [7406] test_07406.jpg → Label: Real, Class: human_faces
# [7407] test_07407.jpg → Label: Real, Class: human_faces
# [7408] test_07408.jpg → Label: Real, Class: human_faces
# [7409] test_07409.jpg → Label: Real, Class: human_faces
# [7410] test_07410.jpg → Label: Real, Class: human_faces
# [7411] test_07411.jpg → Label: Real, Class: human_faces
# [7412] test_07412.jpg → Label: Real, Class: human_faces
# [7413] test_07413.jpg → Label: Real, Class: human_faces
# [7414] test_07414.jpg → Label: Real, Class: human_faces
# [7415] test_07415.jpg → Label: Real, Class: human_faces
# [7416] test_07416.jpg → Label: Real, Class: human_faces
# [7417] test_07417.jpg → Label: Real, Class: human_faces
# [7418] test_07418.jpg → Label: Real, Class: human_faces
# [7419] test_07419.jpg → Label: Real, Class: human_faces
# [7420] test_07420.jpg → Label: Real, Class: human_faces
# [7421] test_07421.jpg → Label: Real, Class: human_faces
# [7422] test_07422.jpg → Label: Real, Class: human_faces
# [7423] test_07423.jpg → Label: Real, Class: human_faces
# [7424] test_07424.jpg → Label: Real, Class: human_faces
# [7425] test_07425.jpg → Label: Real, Class: human_faces
# [7426] test_07426.jpg → Label: Real, Class: human_faces
# [7427] test_07427.jpg → Label: Real, Class: human_faces
# [7428] test_07428.jpg → Label: Real, Class: human_faces
# [7429] test_07429.jpg → Label: Real, Class: human_faces
# [7430] test_07430.jpg → Label: Real, Class: human_faces
# [7431] test_07431.jpg → Label: Real, Class: human_faces
# [7432] test_07432.jpg → Label: Real, Class: human_faces
# [7433] test_07433.jpg → Label: Real, Class: human_faces
# [7434] test_07434.jpg → Label: Real, Class: human_faces
# [7435] test_07435.jpg → Label: Real, Class: human_faces
# [7436] test_07436.jpg → Label: Real, Class: human_faces
# [7437] test_07437.jpg → Label: Real, Class: human_faces
# [7438] test_07438.jpg → Label: Real, Class: human_faces
# [7439] test_07439.jpg → Label: Real, Class: human_faces
# [7440] test_07440.jpg → Label: Real, Class: human_faces
# [7441] test_07441.jpg → Label: Real, Class: human_faces
# [7442] test_07442.jpg → Label: Real, Class: human_faces
# [7443] test_07443.jpg → Label: Real, Class: human_faces
# [7444] test_07444.jpg → Label: Real, Class: human_faces
# [7445] test_07445.jpg → Label: Real, Class: human_faces
# [7446] test_07446.jpg → Label: Real, Class: human_faces
# [7447] test_07447.jpg → Label: Real, Class: human_faces
# [7448] test_07448.jpg → Label: Real, Class: human_faces
# [7449] test_07449.jpg → Label: Real, Class: human_faces
# [7450] test_07450.jpg → Label: Real, Class: human_faces
# [7451] test_07451.jpg → Label: Real, Class: human_faces
# [7452] test_07452.jpg → Label: Real, Class: human_faces
# [7453] test_07453.jpg → Label: Real, Class: human_faces
# [7454] test_07454.jpg → Label: Real, Class: human_faces
# [7455] test_07455.jpg → Label: Real, Class: human_faces
# [7456] test_07456.jpg → Label: Real, Class: human_faces
# [7457] test_07457.jpg → Label: Real, Class: human_faces
# [7458] test_07458.jpg → Label: Real, Class: human_faces
# [7459] test_07459.jpg → Label: Real, Class: human_faces
# [7460] test_07460.jpg → Label: Real, Class: human_faces
# [7461] test_07461.jpg → Label: Real, Class: human_faces
# [7462] test_07462.jpg → Label: Real, Class: human_faces
# [7463] test_07463.jpg → Label: Real, Class: human_faces
# [7464] test_07464.jpg → Label: Real, Class: human_faces
# [7465] test_07465.jpg → Label: Real, Class: human_faces
# [7466] test_07466.jpg → Label: Real, Class: human_faces
# [7467] test_07467.jpg → Label: Real, Class: human_faces
# [7468] test_07468.jpg → Label: Real, Class: human_faces
# [7469] test_07469.jpg → Label: Real, Class: human_faces
# [7470] test_07470.jpg → Label: Real, Class: human_faces
# [7471] test_07471.jpg → Label: Real, Class: human_faces
# [7472] test_07472.jpg → Label: Real, Class: human_faces
# [7473] test_07473.jpg → Label: Real, Class: human_faces
# [7474] test_07474.jpg → Label: Real, Class: human_faces
# [7475] test_07475.jpg → Label: Real, Class: human_faces
# [7476] test_07476.jpg → Label: Real, Class: human_faces
# [7477] test_07477.jpg → Label: Real, Class: human_faces
# [7478] test_07478.jpg → Label: Real, Class: human_faces
# [7479] test_07479.jpg → Label: Real, Class: human_faces
# [7480] test_07480.jpg → Label: Real, Class: human_faces
# [7481] test_07481.jpg → Label: Real, Class: human_faces
# [7482] test_07482.jpg → Label: Real, Class: human_faces
# [7483] test_07483.jpg → Label: Real, Class: human_faces
# [7484] test_07484.jpg → Label: Real, Class: human_faces
# [7485] test_07485.jpg → Label: Real, Class: human_faces
# [7486] test_07486.jpg → Label: Real, Class: human_faces
# [7487] test_07487.jpg → Label: Real, Class: human_faces
# [7488] test_07488.jpg → Label: Real, Class: human_faces
# [7489] test_07489.jpg → Label: Real, Class: human_faces
# [7490] test_07490.jpg → Label: Real, Class: human_faces
# [7491] test_07491.jpg → Label: Real, Class: human_faces
# [7492] test_07492.jpg → Label: Real, Class: human_faces
# [7493] test_07493.jpg → Label: Real, Class: human_faces
# [7494] test_07494.jpg → Label: Real, Class: human_faces
# [7495] test_07495.jpg → Label: Real, Class: human_faces
# [7496] test_07496.jpg → Label: Real, Class: human_faces
# [7497] test_07497.jpg → Label: Real, Class: human_faces
# [7498] test_07498.jpg → Label: Real, Class: human_faces
# [7499] test_07499.jpg → Label: Real, Class: human_faces
# [7500] test_07500.jpg → Label: Real, Class: human_faces
# [7501] test_07501.jpg → Label: Real, Class: human_faces
# [7502] test_07502.jpg → Label: Real, Class: human_faces
# [7503] test_07503.jpg → Label: Real, Class: human_faces
# [7504] test_07504.jpg → Label: Real, Class: human_faces
# [7505] test_07505.jpg → Label: Real, Class: human_faces
# [7506] test_07506.jpg → Label: Real, Class: human_faces
# [7507] test_07507.jpg → Label: Real, Class: human_faces
# [7508] test_07508.jpg → Label: Real, Class: human_faces
# [7509] test_07509.jpg → Label: Real, Class: human_faces
# [7510] test_07510.jpg → Label: Real, Class: human_faces
# [7511] test_07511.jpg → Label: Real, Class: human_faces
# [7512] test_07512.jpg → Label: Real, Class: human_faces
# [7513] test_07513.jpg → Label: Real, Class: human_faces
# [7514] test_07514.jpg → Label: Real, Class: human_faces
# [7515] test_07515.jpg → Label: Real, Class: human_faces
# [7516] test_07516.jpg → Label: Real, Class: human_faces
# [7517] test_07517.jpg → Label: Real, Class: human_faces
# [7518] test_07518.jpg → Label: Real, Class: human_faces
# [7519] test_07519.jpg → Label: Real, Class: human_faces
# [7520] test_07520.jpg → Label: Real, Class: human_faces
# [7521] test_07521.jpg → Label: Real, Class: human_faces
# [7522] test_07522.jpg → Label: Real, Class: human_faces
# [7523] test_07523.jpg → Label: Real, Class: human_faces
# [7524] test_07524.jpg → Label: Real, Class: human_faces
# [7525] test_07525.jpg → Label: Real, Class: human_faces
# [7526] test_07526.jpg → Label: Real, Class: human_faces
# [7527] test_07527.jpg → Label: Real, Class: human_faces
# [7528] test_07528.jpg → Label: Real, Class: human_faces
# [7529] test_07529.jpg → Label: Real, Class: human_faces
# [7530] test_07530.jpg → Label: Real, Class: human_faces
# [7531] test_07531.jpg → Label: Real, Class: human_faces
# [7532] test_07532.jpg → Label: Real, Class: human_faces
# [7533] test_07533.jpg → Label: Real, Class: human_faces
# [7534] test_07534.jpg → Label: Real, Class: human_faces
# [7535] test_07535.jpg → Label: Real, Class: human_faces
# [7536] test_07536.jpg → Label: Real, Class: human_faces
# [7537] test_07537.jpg → Label: Real, Class: human_faces
# [7538] test_07538.jpg → Label: Real, Class: human_faces
# [7539] test_07539.jpg → Label: Real, Class: human_faces
# [7540] test_07540.jpg → Label: Real, Class: human_faces
# [7541] test_07541.jpg → Label: Real, Class: human_faces
# [7542] test_07542.jpg → Label: Real, Class: human_faces
# [7543] test_07543.jpg → Label: Real, Class: human_faces
# [7544] test_07544.jpg → Label: Real, Class: human_faces
# [7545] test_07545.jpg → Label: Real, Class: human_faces
# [7546] test_07546.jpg → Label: Real, Class: human_faces
# [7547] test_07547.jpg → Label: Real, Class: human_faces
# [7548] test_07548.jpg → Label: Real, Class: human_faces
# [7549] test_07549.jpg → Label: Real, Class: human_faces
# [7550] test_07550.jpg → Label: Real, Class: human_faces
# [7551] test_07551.jpg → Label: Real, Class: human_faces
# [7552] test_07552.jpg → Label: Real, Class: human_faces
# [7553] test_07553.jpg → Label: Real, Class: human_faces
# [7554] test_07554.jpg → Label: Real, Class: human_faces
# [7555] test_07555.jpg → Label: Real, Class: human_faces
# [7556] test_07556.jpg → Label: Real, Class: human_faces
# [7557] test_07557.jpg → Label: Real, Class: human_faces
# [7558] test_07558.jpg → Label: Real, Class: human_faces
# [7559] test_07559.jpg → Label: Real, Class: human_faces
# [7560] test_07560.jpg → Label: Real, Class: human_faces
# [7561] test_07561.jpg → Label: Real, Class: human_faces
# [7562] test_07562.jpg → Label: Real, Class: human_faces
# [7563] test_07563.jpg → Label: Real, Class: human_faces
# [7564] test_07564.jpg → Label: Real, Class: human_faces
# [7565] test_07565.jpg → Label: Real, Class: human_faces
# [7566] test_07566.jpg → Label: Real, Class: human_faces
# [7567] test_07567.jpg → Label: Real, Class: human_faces
# [7568] test_07568.jpg → Label: Real, Class: human_faces
# [7569] test_07569.jpg → Label: Real, Class: human_faces
# [7570] test_07570.jpg → Label: Real, Class: human_faces
# [7571] test_07571.jpg → Label: Real, Class: human_faces
# [7572] test_07572.jpg → Label: Real, Class: human_faces
# [7573] test_07573.jpg → Label: Real, Class: human_faces
# [7574] test_07574.jpg → Label: Real, Class: human_faces
# [7575] test_07575.jpg → Label: Real, Class: human_faces
# [7576] test_07576.jpg → Label: Real, Class: human_faces
# [7577] test_07577.jpg → Label: Real, Class: human_faces
# [7578] test_07578.jpg → Label: Real, Class: human_faces
# [7579] test_07579.jpg → Label: Real, Class: human_faces
# [7580] test_07580.jpg → Label: Real, Class: human_faces
# [7581] test_07581.jpg → Label: Real, Class: human_faces
# [7582] test_07582.jpg → Label: Real, Class: human_faces
# [7583] test_07583.jpg → Label: Real, Class: human_faces
# [7584] test_07584.jpg → Label: Real, Class: human_faces
# [7585] test_07585.jpg → Label: Real, Class: human_faces
# [7586] test_07586.jpg → Label: Real, Class: human_faces
# [7587] test_07587.jpg → Label: Real, Class: human_faces
# [7588] test_07588.jpg → Label: Real, Class: human_faces
# [7589] test_07589.jpg → Label: Real, Class: human_faces
# [7590] test_07590.jpg → Label: Real, Class: human_faces
# [7591] test_07591.jpg → Label: Real, Class: human_faces
# [7592] test_07592.jpg → Label: Real, Class: human_faces
# [7593] test_07593.jpg → Label: Real, Class: human_faces
# [7594] test_07594.jpg → Label: Real, Class: human_faces
# [7595] test_07595.jpg → Label: Real, Class: human_faces
# [7596] test_07596.jpg → Label: Real, Class: human_faces
# [7597] test_07597.jpg → Label: Real, Class: human_faces
# [7598] test_07598.jpg → Label: Real, Class: human_faces
# [7599] test_07599.jpg → Label: Real, Class: human_faces
# [7600] test_07600.jpg → Label: Real, Class: human_faces
# [7601] test_07601.jpg → Label: Real, Class: human_faces
# [7602] test_07602.jpg → Label: Real, Class: human_faces
# [7603] test_07603.jpg → Label: Real, Class: human_faces
# [7604] test_07604.jpg → Label: Real, Class: human_faces
# [7605] test_07605.jpg → Label: Real, Class: human_faces
# [7606] test_07606.jpg → Label: Real, Class: human_faces
# [7607] test_07607.jpg → Label: Real, Class: human_faces
# [7608] test_07608.jpg → Label: Real, Class: human_faces
# [7609] test_07609.jpg → Label: Real, Class: human_faces
# [7610] test_07610.jpg → Label: Real, Class: human_faces
# [7611] test_07611.jpg → Label: Real, Class: human_faces
# [7612] test_07612.jpg → Label: Real, Class: human_faces
# [7613] test_07613.jpg → Label: Real, Class: human_faces
# [7614] test_07614.jpg → Label: Real, Class: human_faces
# [7615] test_07615.jpg → Label: Real, Class: human_faces
# [7616] test_07616.jpg → Label: Real, Class: human_faces
# [7617] test_07617.jpg → Label: Real, Class: human_faces
# [7618] test_07618.jpg → Label: Real, Class: human_faces
# [7619] test_07619.jpg → Label: Real, Class: human_faces
# [7620] test_07620.jpg → Label: Real, Class: human_faces
# [7621] test_07621.jpg → Label: Real, Class: human_faces
# [7622] test_07622.jpg → Label: Real, Class: human_faces
# [7623] test_07623.jpg → Label: Real, Class: human_faces
# [7624] test_07624.jpg → Label: Real, Class: human_faces
# [7625] test_07625.jpg → Label: Real, Class: human_faces
# [7626] test_07626.jpg → Label: Real, Class: human_faces
# [7627] test_07627.jpg → Label: Real, Class: human_faces
# [7628] test_07628.jpg → Label: Real, Class: human_faces
# [7629] test_07629.jpg → Label: Real, Class: human_faces
# [7630] test_07630.jpg → Label: Real, Class: human_faces
# [7631] test_07631.jpg → Label: Real, Class: human_faces
# [7632] test_07632.jpg → Label: Real, Class: human_faces
# [7633] test_07633.jpg → Label: Real, Class: human_faces
# [7634] test_07634.jpg → Label: Real, Class: human_faces
# [7635] test_07635.jpg → Label: Real, Class: human_faces
# [7636] test_07636.jpg → Label: Real, Class: human_faces
# [7637] test_07637.jpg → Label: Real, Class: human_faces
# [7638] test_07638.jpg → Label: Real, Class: human_faces
# [7639] test_07639.jpg → Label: Real, Class: human_faces
# [7640] test_07640.jpg → Label: Real, Class: human_faces
# [7641] test_07641.jpg → Label: Real, Class: human_faces
# [7642] test_07642.jpg → Label: Real, Class: human_faces
# [7643] test_07643.jpg → Label: Real, Class: human_faces
# [7644] test_07644.jpg → Label: Real, Class: human_faces
# [7645] test_07645.jpg → Label: Real, Class: human_faces
# [7646] test_07646.jpg → Label: Real, Class: human_faces
# [7647] test_07647.jpg → Label: Real, Class: human_faces
# [7648] test_07648.jpg → Label: Real, Class: human_faces
# [7649] test_07649.jpg → Label: Real, Class: human_faces
# [7650] test_07650.jpg → Label: Real, Class: human_faces
# [7651] test_07651.jpg → Label: Real, Class: human_faces
# [7652] test_07652.jpg → Label: Real, Class: human_faces
# [7653] test_07653.jpg → Label: Real, Class: human_faces
# [7654] test_07654.jpg → Label: Real, Class: human_faces
# [7655] test_07655.jpg → Label: Real, Class: human_faces
# [7656] test_07656.jpg → Label: Real, Class: human_faces
# [7657] test_07657.jpg → Label: Real, Class: human_faces
# [7658] test_07658.jpg → Label: Real, Class: human_faces
# [7659] test_07659.jpg → Label: Real, Class: human_faces
# [7660] test_07660.jpg → Label: Real, Class: human_faces
# [7661] test_07661.jpg → Label: Real, Class: human_faces
# [7662] test_07662.jpg → Label: Real, Class: human_faces
# [7663] test_07663.jpg → Label: Real, Class: human_faces
# [7664] test_07664.jpg → Label: Real, Class: human_faces
# [7665] test_07665.jpg → Label: Real, Class: human_faces
# [7666] test_07666.jpg → Label: Real, Class: human_faces
# [7667] test_07667.jpg → Label: Real, Class: human_faces
# [7668] test_07668.jpg → Label: Real, Class: human_faces
# [7669] test_07669.jpg → Label: Real, Class: human_faces
# [7670] test_07670.jpg → Label: Real, Class: human_faces
# [7671] test_07671.jpg → Label: Real, Class: human_faces
# [7672] test_07672.jpg → Label: Real, Class: human_faces
# [7673] test_07673.jpg → Label: Real, Class: human_faces
# [7674] test_07674.jpg → Label: Real, Class: human_faces
# [7675] test_07675.jpg → Label: Real, Class: human_faces
# [7676] test_07676.jpg → Label: Real, Class: human_faces
# [7677] test_07677.jpg → Label: Real, Class: human_faces
# [7678] test_07678.jpg → Label: Real, Class: human_faces
# [7679] test_07679.jpg → Label: Real, Class: human_faces
# [7680] test_07680.jpg → Label: Real, Class: human_faces
# [7681] test_07681.jpg → Label: Real, Class: human_faces
# [7682] test_07682.jpg → Label: Real, Class: human_faces
# [7683] test_07683.jpg → Label: Real, Class: human_faces
# [7684] test_07684.jpg → Label: Real, Class: human_faces
# [7685] test_07685.jpg → Label: Real, Class: human_faces
# [7686] test_07686.jpg → Label: Real, Class: human_faces
# [7687] test_07687.jpg → Label: Real, Class: human_faces
# [7688] test_07688.jpg → Label: Real, Class: human_faces
# [7689] test_07689.jpg → Label: Real, Class: human_faces
# [7690] test_07690.jpg → Label: Real, Class: human_faces
# [7691] test_07691.jpg → Label: Real, Class: human_faces
# [7692] test_07692.jpg → Label: Real, Class: human_faces
# [7693] test_07693.jpg → Label: Real, Class: human_faces
# [7694] test_07694.jpg → Label: Real, Class: human_faces
# [7695] test_07695.jpg → Label: Real, Class: human_faces
# [7696] test_07696.jpg → Label: Real, Class: human_faces
# [7697] test_07697.jpg → Label: Real, Class: human_faces
# [7698] test_07698.jpg → Label: Real, Class: human_faces
# [7699] test_07699.jpg → Label: Real, Class: human_faces
# [7700] test_07700.jpg → Label: Real, Class: human_faces
# [7701] test_07701.jpg → Label: Real, Class: human_faces
# [7702] test_07702.jpg → Label: Real, Class: human_faces
# [7703] test_07703.jpg → Label: Real, Class: human_faces
# [7704] test_07704.jpg → Label: Real, Class: human_faces
# [7705] test_07705.jpg → Label: Real, Class: human_faces
# [7706] test_07706.jpg → Label: Real, Class: human_faces
# [7707] test_07707.jpg → Label: Real, Class: human_faces
# [7708] test_07708.jpg → Label: Real, Class: human_faces
# [7709] test_07709.jpg → Label: Real, Class: human_faces
# [7710] test_07710.jpg → Label: Real, Class: human_faces
# [7711] test_07711.jpg → Label: Real, Class: human_faces
# [7712] test_07712.jpg → Label: Real, Class: human_faces
# [7713] test_07713.jpg → Label: Real, Class: human_faces
# [7714] test_07714.jpg → Label: Real, Class: human_faces
# [7715] test_07715.jpg → Label: Real, Class: human_faces
# [7716] test_07716.jpg → Label: Real, Class: human_faces
# [7717] test_07717.jpg → Label: Real, Class: human_faces
# [7718] test_07718.jpg → Label: Real, Class: human_faces
# [7719] test_07719.jpg → Label: Real, Class: human_faces
# [7720] test_07720.jpg → Label: Real, Class: human_faces
# [7721] test_07721.jpg → Label: Real, Class: human_faces
# [7722] test_07722.jpg → Label: Real, Class: human_faces
# [7723] test_07723.jpg → Label: Real, Class: human_faces
# [7724] test_07724.jpg → Label: Real, Class: human_faces
# [7725] test_07725.jpg → Label: Real, Class: human_faces
# [7726] test_07726.jpg → Label: Real, Class: human_faces
# [7727] test_07727.jpg → Label: Real, Class: human_faces
# [7728] test_07728.jpg → Label: Real, Class: human_faces
# [7729] test_07729.jpg → Label: Real, Class: human_faces
# [7730] test_07730.jpg → Label: Real, Class: human_faces
# [7731] test_07731.jpg → Label: Real, Class: human_faces
# [7732] test_07732.jpg → Label: Real, Class: human_faces
# [7733] test_07733.jpg → Label: Real, Class: human_faces
# [7734] test_07734.jpg → Label: Real, Class: human_faces
# [7735] test_07735.jpg → Label: Real, Class: human_faces
# [7736] test_07736.jpg → Label: Real, Class: human_faces
# [7737] test_07737.jpg → Label: Real, Class: human_faces
# [7738] test_07738.jpg → Label: Real, Class: human_faces
# [7739] test_07739.jpg → Label: Real, Class: human_faces
# [7740] test_07740.jpg → Label: Real, Class: human_faces
# [7741] test_07741.jpg → Label: Real, Class: human_faces
# [7742] test_07742.jpg → Label: Real, Class: human_faces
# [7743] test_07743.jpg → Label: Real, Class: human_faces
# [7744] test_07744.jpg → Label: Real, Class: human_faces
# [7745] test_07745.jpg → Label: Real, Class: human_faces
# [7746] test_07746.jpg → Label: Real, Class: human_faces
# [7747] test_07747.jpg → Label: Real, Class: human_faces
# [7748] test_07748.jpg → Label: Real, Class: human_faces
# [7749] test_07749.jpg → Label: Real, Class: human_faces
# [7750] test_07750.jpg → Label: Real, Class: human_faces
# [7751] test_07751.jpg → Label: Real, Class: human_faces
# [7752] test_07752.jpg → Label: Real, Class: human_faces
# [7753] test_07753.jpg → Label: Real, Class: human_faces
# [7754] test_07754.jpg → Label: Real, Class: human_faces
# [7755] test_07755.jpg → Label: Real, Class: human_faces
# [7756] test_07756.jpg → Label: Real, Class: human_faces
# [7757] test_07757.jpg → Label: Real, Class: human_faces
# [7758] test_07758.jpg → Label: Real, Class: human_faces
# [7759] test_07759.jpg → Label: Real, Class: human_faces
# [7760] test_07760.jpg → Label: Real, Class: human_faces
# [7761] test_07761.jpg → Label: Real, Class: human_faces
# [7762] test_07762.jpg → Label: Real, Class: human_faces
# [7763] test_07763.jpg → Label: Real, Class: human_faces
# [7764] test_07764.jpg → Label: Real, Class: human_faces
# [7765] test_07765.jpg → Label: Real, Class: human_faces
# [7766] test_07766.jpg → Label: Real, Class: human_faces
# [7767] test_07767.jpg → Label: Real, Class: human_faces
# [7768] test_07768.jpg → Label: Real, Class: human_faces
# [7769] test_07769.jpg → Label: Real, Class: human_faces
# [7770] test_07770.jpg → Label: Real, Class: human_faces
# [7771] test_07771.jpg → Label: Real, Class: human_faces
# [7772] test_07772.jpg → Label: Real, Class: human_faces
# [7773] test_07773.jpg → Label: Real, Class: human_faces
# [7774] test_07774.jpg → Label: Real, Class: human_faces
# [7775] test_07775.jpg → Label: Real, Class: human_faces
# [7776] test_07776.jpg → Label: Real, Class: human_faces
# [7777] test_07777.jpg → Label: Real, Class: human_faces
# [7778] test_07778.jpg → Label: Real, Class: human_faces
# [7779] test_07779.jpg → Label: Real, Class: human_faces
# [7780] test_07780.jpg → Label: Real, Class: human_faces
# [7781] test_07781.jpg → Label: Real, Class: human_faces
# [7782] test_07782.jpg → Label: Real, Class: human_faces
# [7783] test_07783.jpg → Label: Real, Class: human_faces
# [7784] test_07784.jpg → Label: Real, Class: human_faces
# [7785] test_07785.jpg → Label: Real, Class: human_faces
# [7786] test_07786.jpg → Label: Real, Class: human_faces
# [7787] test_07787.jpg → Label: Real, Class: human_faces
# [7788] test_07788.jpg → Label: Real, Class: human_faces
# [7789] test_07789.jpg → Label: Real, Class: human_faces
# [7790] test_07790.jpg → Label: Real, Class: human_faces
# [7791] test_07791.jpg → Label: Real, Class: human_faces
# [7792] test_07792.jpg → Label: Real, Class: human_faces
# [7793] test_07793.jpg → Label: Real, Class: human_faces
# [7794] test_07794.jpg → Label: Real, Class: human_faces
# [7795] test_07795.jpg → Label: Real, Class: human_faces
# [7796] test_07796.jpg → Label: Real, Class: human_faces
# [7797] test_07797.jpg → Label: Real, Class: human_faces
# [7798] test_07798.jpg → Label: Real, Class: human_faces
# [7799] test_07799.jpg → Label: Real, Class: human_faces
# [7800] test_07800.jpg → Label: Real, Class: human_faces
# [7801] test_07801.jpg → Label: Real, Class: human_faces
# [7802] test_07802.jpg → Label: Real, Class: human_faces
# [7803] test_07803.jpg → Label: Real, Class: human_faces
# [7804] test_07804.jpg → Label: Real, Class: human_faces
# [7805] test_07805.jpg → Label: Real, Class: human_faces
# [7806] test_07806.jpg → Label: Real, Class: human_faces
# [7807] test_07807.jpg → Label: Real, Class: human_faces
# [7808] test_07808.jpg → Label: Real, Class: human_faces
# [7809] test_07809.jpg → Label: Real, Class: human_faces
# [7810] test_07810.jpg → Label: Real, Class: human_faces
# [7811] test_07811.jpg → Label: Real, Class: human_faces
# [7812] test_07812.jpg → Label: Real, Class: human_faces
# [7813] test_07813.jpg → Label: Real, Class: human_faces
# [7814] test_07814.jpg → Label: Real, Class: human_faces
# [7815] test_07815.jpg → Label: Real, Class: human_faces
# [7816] test_07816.jpg → Label: Real, Class: human_faces
# [7817] test_07817.jpg → Label: Real, Class: human_faces
# [7818] test_07818.jpg → Label: Real, Class: human_faces
# [7819] test_07819.jpg → Label: Real, Class: human_faces
# [7820] test_07820.jpg → Label: Real, Class: human_faces
# [7821] test_07821.jpg → Label: Real, Class: human_faces
# [7822] test_07822.jpg → Label: Real, Class: human_faces
# [7823] test_07823.jpg → Label: Real, Class: human_faces
# [7824] test_07824.jpg → Label: Real, Class: human_faces
# [7825] test_07825.jpg → Label: Real, Class: human_faces
# [7826] test_07826.jpg → Label: Real, Class: human_faces
# [7827] test_07827.jpg → Label: Real, Class: human_faces
# [7828] test_07828.jpg → Label: Real, Class: human_faces
# [7829] test_07829.jpg → Label: Real, Class: human_faces
# [7830] test_07830.jpg → Label: Real, Class: human_faces
# [7831] test_07831.jpg → Label: Real, Class: human_faces
# [7832] test_07832.jpg → Label: Real, Class: human_faces
# [7833] test_07833.jpg → Label: Real, Class: human_faces
# [7834] test_07834.jpg → Label: Real, Class: human_faces
# [7835] test_07835.jpg → Label: Real, Class: human_faces
# [7836] test_07836.jpg → Label: Real, Class: human_faces
# [7837] test_07837.jpg → Label: Real, Class: human_faces
# [7838] test_07838.jpg → Label: Real, Class: human_faces
# [7839] test_07839.jpg → Label: Real, Class: human_faces
# [7840] test_07840.jpg → Label: Real, Class: human_faces
# [7841] test_07841.jpg → Label: Real, Class: human_faces
# [7842] test_07842.jpg → Label: Real, Class: human_faces
# [7843] test_07843.jpg → Label: Real, Class: human_faces
# [7844] test_07844.jpg → Label: Real, Class: human_faces
# [7845] test_07845.jpg → Label: Real, Class: human_faces
# [7846] test_07846.jpg → Label: Real, Class: human_faces
# [7847] test_07847.jpg → Label: Real, Class: human_faces
# [7848] test_07848.jpg → Label: Real, Class: human_faces
# [7849] test_07849.jpg → Label: Real, Class: human_faces
# [7850] test_07850.jpg → Label: Real, Class: human_faces
# [7851] test_07851.jpg → Label: Real, Class: human_faces
# [7852] test_07852.jpg → Label: Real, Class: human_faces
# [7853] test_07853.jpg → Label: Real, Class: human_faces
# [7854] test_07854.jpg → Label: Real, Class: human_faces
# [7855] test_07855.jpg → Label: Real, Class: human_faces
# [7856] test_07856.jpg → Label: Real, Class: human_faces
# [7857] test_07857.jpg → Label: Real, Class: human_faces
# [7858] test_07858.jpg → Label: Real, Class: human_faces
# ...
# [11724] test_11724.jpg → Label: Real, Class: human_faces
# [11725] test_11725.jpg → Label: Real, Class: human_faces
# [11726] test_11726.jpg → Label: Real, Class: human_faces
# [11727] test_11727.jpg → Label: Real, Class: human_faces
# [11728] test_11728.jpg → Label: Real, Class: human_faces
# [11729] test_11729.jpg → Label: Real, Class: human_faces
# [11730] test_11730.jpg → Label: Real, Class: human_faces
# [11731] test_11731.jpg → Label: Real, Class: human_faces
# [11732] test_11732.jpg → Label: Real, Class: human_faces
# [11733] test_11733.jpg → Label: Real, Class: human_faces
# [11734] test_11734.jpg → Label: Real, Class: human_faces
# [11735] test_11735.jpg → Label: Real, Class: human_faces
# [11736] test_11736.jpg → Label: Real, Class: human_faces
# [11737] test_11737.jpg → Label: Real, Class: human_faces
# [11738] test_11738.jpg → Label: Real, Class: human_faces
# [11739] test_11739.jpg → Label: Real, Class: human_faces
# [11740] test_11740.jpg → Label: Real, Class: human_faces
# [11741] test_11741.jpg → Label: Real, Class: human_faces
# [11742] test_11742.jpg → Label: Real, Class: human_faces
# [11743] test_11743.jpg → Label: Real, Class: human_faces
# [11744] test_11744.jpg → Label: Real, Class: human_faces
# [11745] test_11745.jpg → Label: Real, Class: human_faces
# [11746] test_11746.jpg → Label: Real, Class: human_faces
# [11747] test_11747.jpg → Label: Real, Class: human_faces
# [11748] test_11748.jpg → Label: Real, Class: human_faces
# [11749] test_11749.jpg → Label: Real, Class: human_faces
# [11750] test_11750.jpg → Label: Real, Class: human_faces
# [11751] test_11751.jpg → Label: Real, Class: human_faces
# [11752] test_11752.jpg → Label: Real, Class: human_faces
# [11753] test_11753.jpg → Label: Real, Class: human_faces
# [11754] test_11754.jpg → Label: Real, Class: human_faces
# [11755] test_11755.jpg → Label: Real, Class: human_faces
# [11756] test_11756.jpg → Label: Real, Class: human_faces
# [11757] test_11757.jpg → Label: Real, Class: human_faces
# [11758] test_11758.jpg → Label: Real, Class: human_faces
# [11759] test_11759.jpg → Label: Real, Class: human_faces
# [11760] test_11760.jpg → Label: Real, Class: human_faces
# [11761] test_11761.jpg → Label: Real, Class: human_faces
# [11762] test_11762.jpg → Label: Real, Class: human_faces
# [11763] test_11763.jpg → Label: Real, Class: human_faces
# [11764] test_11764.jpg → Label: Real, Class: human_faces
# [11765] test_11765.jpg → Label: Real, Class: human_faces
# [11766] test_11766.jpg → Label: Real, Class: human_faces
# [11767] test_11767.jpg → Label: Real, Class: human_faces
# [11768] test_11768.jpg → Label: Real, Class: human_faces
# [11769] test_11769.jpg → Label: Real, Class: human_faces
# [11770] test_11770.jpg → Label: Real, Class: human_faces
# [11771] test_11771.jpg → Label: Real, Class: human_faces
# [11772] test_11772.jpg → Label: Real, Class: human_faces
# [11773] test_11773.jpg → Label: Real, Class: human_faces
# [11774] test_11774.jpg → Label: Real, Class: human_faces
# [11775] test_11775.jpg → Label: Real, Class: human_faces
# [11776] test_11776.jpg → Label: Real, Class: human_faces
# [11777] test_11777.jpg → Label: Real, Class: human_faces
# [11778] test_11778.jpg → Label: Real, Class: human_faces
# [11779] test_11779.jpg → Label: Real, Class: human_faces
# [11780] test_11780.jpg → Label: Real, Class: human_faces
# [11781] test_11781.jpg → Label: Real, Class: human_faces
# [11782] test_11782.jpg → Label: Real, Class: human_faces
# [11783] test_11783.jpg → Label: Real, Class: human_faces
# [11784] test_11784.jpg → Label: Real, Class: human_faces
# [11785] test_11785.jpg → Label: Real, Class: human_faces
# [11786] test_11786.jpg → Label: Real, Class: human_faces
# [11787] test_11787.jpg → Label: Real, Class: human_faces
# [11788] test_11788.jpg → Label: Real, Class: human_faces
# [11789] test_11789.jpg → Label: Real, Class: human_faces
# [11790] test_11790.jpg → Label: Real, Class: human_faces
# [11791] test_11791.jpg → Label: Real, Class: human_faces
# [11792] test_11792.jpg → Label: Real, Class: human_faces
# [11793] test_11793.jpg → Label: Real, Class: human_faces
# [11794] test_11794.jpg → Label: Real, Class: human_faces
# [11795] test_11795.jpg → Label: Real, Class: human_faces
# [11796] test_11796.jpg → Label: Real, Class: human_faces
# [11797] test_11797.jpg → Label: Real, Class: human_faces
# [11798] test_11798.jpg → Label: Real, Class: human_faces
# [11799] test_11799.jpg → Label: Real, Class: human_faces
# [11800] test_11800.jpg → Label: Real, Class: human_faces
# [11801] test_11801.jpg → Label: Real, Class: human_faces
# [11802] test_11802.jpg → Label: Real, Class: human_faces
# [11803] test_11803.jpg → Label: Real, Class: human_faces
# [11804] test_11804.jpg → Label: Real, Class: human_faces
# [11805] test_11805.jpg → Label: Real, Class: human_faces
# [11806] test_11806.jpg → Label: Real, Class: human_faces
# [11807] test_11807.jpg → Label: Real, Class: human_faces
# [11808] test_11808.jpg → Label: Real, Class: human_faces
# [11809] test_11809.jpg → Label: Real, Class: human_faces
# [11810] test_11810.jpg → Label: Real, Class: human_faces
# [11811] test_11811.jpg → Label: Real, Class: human_faces
# [11812] test_11812.jpg → Label: Real, Class: human_faces
# [11813] test_11813.jpg → Label: Real, Class: human_faces
# [11814] test_11814.jpg → Label: Real, Class: human_faces
# [11815] test_11815.jpg → Label: Real, Class: human_faces
# [11816] test_11816.jpg → Label: Real, Class: human_faces
# [11817] test_11817.jpg → Label: Real, Class: human_faces
# [11818] test_11818.jpg → Label: Real, Class: human_faces
# [11819] test_11819.jpg → Label: Real, Class: human_faces
# [11820] test_11820.jpg → Label: Real, Class: human_faces
# [11821] test_11821.jpg → Label: Real, Class: human_faces
# [11822] test_11822.jpg → Label: Real, Class: human_faces
# [11823] test_11823.jpg → Label: Real, Class: human_faces
# [11824] test_11824.jpg → Label: Real, Class: human_faces
# [11825] test_11825.jpg → Label: Real, Class: human_faces
# [11826] test_11826.jpg → Label: Real, Class: human_faces
# [11827] test_11827.jpg → Label: Real, Class: human_faces
# [11828] test_11828.jpg → Label: Real, Class: human_faces
# [11829] test_11829.jpg → Label: Real, Class: human_faces
# [11830] test_11830.jpg → Label: Real, Class: human_faces
# [11831] test_11831.jpg → Label: Real, Class: human_faces
# [11832] test_11832.jpg → Label: Real, Class: human_faces
# [11833] test_11833.jpg → Label: Real, Class: human_faces
# [11834] test_11834.jpg → Label: Real, Class: human_faces
# [11835] test_11835.jpg → Label: Real, Class: human_faces
# [11836] test_11836.jpg → Label: Real, Class: human_faces
# [11837] test_11837.jpg → Label: Real, Class: human_faces
# [11838] test_11838.jpg → Label: Real, Class: human_faces
# [11839] test_11839.jpg → Label: Real, Class: human_faces
# [11840] test_11840.jpg → Label: Real, Class: human_faces
# [11841] test_11841.jpg → Label: Real, Class: human_faces
# [11842] test_11842.jpg → Label: Real, Class: human_faces
# [11843] test_11843.jpg → Label: Real, Class: human_faces
# [11844] test_11844.jpg → Label: Real, Class: human_faces
# [11845] test_11845.jpg → Label: Real, Class: human_faces
# [11846] test_11846.jpg → Label: Real, Class: human_faces
# [11847] test_11847.jpg → Label: Real, Class: human_faces
# [11848] test_11848.jpg → Label: Real, Class: human_faces
# [11849] test_11849.jpg → Label: Real, Class: human_faces
# [11850] test_11850.jpg → Label: Real, Class: human_faces
# [11851] test_11851.jpg → Label: Real, Class: human_faces
# [11852] test_11852.jpg → Label: Real, Class: human_faces
# [11853] test_11853.jpg → Label: Real, Class: human_faces
# [11854] test_11854.jpg → Label: Real, Class: human_faces
# [11855] test_11855.jpg → Label: Real, Class: human_faces
# [11856] test_11856.jpg → Label: Real, Class: human_faces
# [11857] test_11857.jpg → Label: Real, Class: human_faces
# [11858] test_11858.jpg → Label: Real, Class: human_faces
# [11859] test_11859.jpg → Label: Real, Class: human_faces
# [11860] test_11860.jpg → Label: Real, Class: human_faces
# [11861] test_11861.jpg → Label: Real, Class: human_faces
# [11862] test_11862.jpg → Label: Real, Class: human_faces
# [11863] test_11863.jpg → Label: Real, Class: human_faces
# [11864] test_11864.jpg → Label: Real, Class: human_faces
# [11865] test_11865.jpg → Label: Real, Class: human_faces
# [11866] test_11866.jpg → Label: Real, Class: human_faces
# [11867] test_11867.jpg → Label: Real, Class: human_faces
# [11868] test_11868.jpg → Label: Real, Class: human_faces
# [11869] test_11869.jpg → Label: Real, Class: human_faces
# [11870] test_11870.jpg → Label: Real, Class: human_faces
# [11871] test_11871.jpg → Label: Real, Class: human_faces
# [11872] test_11872.jpg → Label: Real, Class: human_faces
# [11873] test_11873.jpg → Label: Real, Class: human_faces
# [11874] test_11874.jpg → Label: Real, Class: human_faces
# [11875] test_11875.jpg → Label: Real, Class: human_faces
# [11876] test_11876.jpg → Label: Real, Class: human_faces
# [11877] test_11877.jpg → Label: Real, Class: human_faces
# [11878] test_11878.jpg → Label: Real, Class: human_faces
# [11879] test_11879.jpg → Label: Real, Class: human_faces
# [11880] test_11880.jpg → Label: Real, Class: human_faces
# [11881] test_11881.jpg → Label: Real, Class: human_faces
# [11882] test_11882.jpg → Label: Real, Class: human_faces
# [11883] test_11883.jpg → Label: Real, Class: human_faces
# [11884] test_11884.jpg → Label: Real, Class: human_faces
# [11885] test_11885.jpg → Label: Real, Class: human_faces
# [11886] test_11886.jpg → Label: Real, Class: human_faces
# [11887] test_11887.jpg → Label: Real, Class: human_faces
# [11888] test_11888.jpg → Label: Real, Class: human_faces
# [11889] test_11889.jpg → Label: Real, Class: human_faces
# [11890] test_11890.jpg → Label: Real, Class: human_faces
# [11891] test_11891.jpg → Label: Real, Class: human_faces
# [11892] test_11892.jpg → Label: Real, Class: human_faces
# [11893] test_11893.jpg → Label: Real, Class: human_faces
# [11894] test_11894.jpg → Label: Real, Class: human_faces
# [11895] test_11895.jpg → Label: Real, Class: human_faces
# [11896] test_11896.jpg → Label: Real, Class: human_faces
# [11897] test_11897.jpg → Label: Real, Class: human_faces
# [11898] test_11898.jpg → Label: Real, Class: human_faces
# [11899] test_11899.jpg → Label: Real, Class: human_faces
# [11900] test_11900.jpg → Label: Real, Class: human_faces
# [11901] test_11901.jpg → Label: Real, Class: human_faces
# [11902] test_11902.jpg → Label: Real, Class: human_faces
# [11903] test_11903.jpg → Label: Real, Class: human_faces
# [11904] test_11904.jpg → Label: Real, Class: human_faces
# [11905] test_11905.jpg → Label: Real, Class: human_faces
# [11906] test_11906.jpg → Label: Real, Class: human_faces
# [11907] test_11907.jpg → Label: Real, Class: human_faces
# [11908] test_11908.jpg → Label: Real, Class: human_faces
# [11909] test_11909.jpg → Label: Real, Class: human_faces
# [11910] test_11910.jpg → Label: Real, Class: human_faces
# [11911] test_11911.jpg → Label: Real, Class: human_faces
# [11912] test_11912.jpg → Label: Real, Class: human_faces
# [11913] test_11913.jpg → Label: Real, Class: human_faces
# [11914] test_11914.jpg → Label: Real, Class: human_faces
# [11915] test_11915.jpg → Label: Real, Class: human_faces
# [11916] test_11916.jpg → Label: Real, Class: human_faces
# [11917] test_11917.jpg → Label: Real, Class: human_faces
# [11918] test_11918.jpg → Label: Real, Class: human_faces
# [11919] test_11919.jpg → Label: Real, Class: human_faces
# [11920] test_11920.jpg → Label: Real, Class: human_faces
# [11921] test_11921.jpg → Label: Real, Class: human_faces
# [11922] test_11922.jpg → Label: Real, Class: human_faces
# [11923] test_11923.jpg → Label: Real, Class: human_faces
# [11924] test_11924.jpg → Label: Real, Class: human_faces
# [11925] test_11925.jpg → Label: Real, Class: human_faces
# [11926] test_11926.jpg → Label: Real, Class: human_faces
# [11927] test_11927.jpg → Label: Real, Class: human_faces
# [11928] test_11928.jpg → Label: Real, Class: human_faces
# [11929] test_11929.jpg → Label: Real, Class: human_faces
# [11930] test_11930.jpg → Label: Real, Class: human_faces
# [11931] test_11931.jpg → Label: Real, Class: human_faces
# [11932] test_11932.jpg → Label: Real, Class: human_faces
# [11933] test_11933.jpg → Label: Real, Class: human_faces
# [11934] test_11934.jpg → Label: Real, Class: human_faces
# [11935] test_11935.jpg → Label: Real, Class: human_faces
# [11936] test_11936.jpg → Label: Real, Class: human_faces
# [11937] test_11937.jpg → Label: Real, Class: human_faces
# [11938] test_11938.jpg → Label: Real, Class: human_faces
# [11939] test_11939.jpg → Label: Real, Class: human_faces
# [11940] test_11940.jpg → Label: Real, Class: human_faces
# [11941] test_11941.jpg → Label: Real, Class: human_faces
# [11942] test_11942.jpg → Label: Real, Class: human_faces
# [11943] test_11943.jpg → Label: Real, Class: human_faces
# [11944] test_11944.jpg → Label: Real, Class: human_faces
# [11945] test_11945.jpg → Label: Real, Class: human_faces
# [11946] test_11946.jpg → Label: Real, Class: human_faces
# [11947] test_11947.jpg → Label: Real, Class: human_faces
# [11948] test_11948.jpg → Label: Real, Class: human_faces
# [11949] test_11949.jpg → Label: Real, Class: human_faces
# [11950] test_11950.jpg → Label: Real, Class: human_faces
# [11951] test_11951.jpg → Label: Real, Class: human_faces
# [11952] test_11952.jpg → Label: Real, Class: human_faces
# [11953] test_11953.jpg → Label: Real, Class: human_faces
# [11954] test_11954.jpg → Label: Real, Class: human_faces
# [11955] test_11955.jpg → Label: Real, Class: human_faces
# [11956] test_11956.jpg → Label: Real, Class: human_faces
# [11957] test_11957.jpg → Label: Real, Class: human_faces
# [11958] test_11958.jpg → Label: Real, Class: human_faces
# [11959] test_11959.jpg → Label: Real, Class: human_faces
# [11960] test_11960.jpg → Label: Real, Class: human_faces
# [11961] test_11961.jpg → Label: Real, Class: human_faces
# [11962] test_11962.jpg → Label: Real, Class: human_faces
# [11963] test_11963.jpg → Label: Real, Class: human_faces
# [11964] test_11964.jpg → Label: Real, Class: human_faces
# [11965] test_11965.jpg → Label: Real, Class: human_faces
# [11966] test_11966.jpg → Label: Real, Class: human_faces
# [11967] test_11967.jpg → Label: Real, Class: human_faces
# [11968] test_11968.jpg → Label: Real, Class: human_faces
# [11969] test_11969.jpg → Label: Real, Class: human_faces
# [11970] test_11970.jpg → Label: Real, Class: human_faces
# [11971] test_11971.jpg → Label: Real, Class: human_faces
# [11972] test_11972.jpg → Label: Real, Class: human_faces
# [11973] test_11973.jpg → Label: Real, Class: human_faces
# [11974] test_11974.jpg → Label: Real, Class: human_faces
# [11975] test_11975.jpg → Label: Real, Class: human_faces
# [11976] test_11976.jpg → Label: Real, Class: human_faces
# [11977] test_11977.jpg → Label: Real, Class: human_faces
# [11978] test_11978.jpg → Label: Real, Class: human_faces
# [11979] test_11979.jpg → Label: Real, Class: human_faces
# [11980] test_11980.jpg → Label: Real, Class: human_faces
# [11981] test_11981.jpg → Label: Real, Class: human_faces
# [11982] test_11982.jpg → Label: Real, Class: human_faces
# [11983] test_11983.jpg → Label: Real, Class: human_faces
# [11984] test_11984.jpg → Label: Real, Class: human_faces
# [11985] test_11985.jpg → Label: Real, Class: human_faces
# [11986] test_11986.jpg → Label: Real, Class: human_faces
# [11987] test_11987.jpg → Label: Real, Class: human_faces
# [11988] test_11988.jpg → Label: Real, Class: human_faces
# [11989] test_11989.jpg → Label: Real, Class: human_faces
# [11990] test_11990.jpg → Label: Real, Class: human_faces
# [11991] test_11991.jpg → Label: Real, Class: human_faces
# [11992] test_11992.jpg → Label: Real, Class: human_faces
# [11993] test_11993.jpg → Label: Real, Class: human_faces
# [11994] test_11994.jpg → Label: Real, Class: human_faces
# [11995] test_11995.jpg → Label: Real, Class: human_faces
# [11996] test_11996.jpg → Label: Real, Class: human_faces
# [11997] test_11997.jpg → Label: Real, Class: human_faces
# [11998] test_11998.jpg → Label: Real, Class: human_faces
# [11999] test_11999.jpg → Label: Real, Class: human_faces
# [12000] test_12000.jpg → Label: Real, Class: human_faces
# [12001] test_12001.jpg → Label: Real, Class: human_faces
# [12002] test_12002.jpg → Label: Real, Class: human_faces
#
# ✅ Done! Total images tested: 12002
# 📄 test.csv saved.

# %%
model = load_model("deepfake_model.h5")  # Confirm this is trained from Xception
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
print(f"[{image_count}] {fname}")
print(f"  → label_pred: {label_pred[0][0]:.4f}")
print(f"  → class_pred: {class_pred[0]}, class = {class_names[np.argmax(class_pred[0])]}")
# Out:
# [12002] test_12002.jpg
#   → label_pred: 0.9424
#   → class_pred: [0.89327633 0.04826102 0.05846265], class = human_faces

# %%
from collections import Counter

train_gen = DeepfakeDataGenerator(train_dir, batch_size=32, img_size=(299, 299))
class_distribution = Counter(train_gen.classes)
label_distribution = Counter(train_gen.labels)

print("Class Distribution:", class_distribution)
print("Label Distribution:", label_distribution)
# Out:
# Class Distribution: Counter({'human_faces': 84000, 'vehicles': 58798, 'animals': 25200})
# Label Distribution: Counter({1: 83999, 0: 83999})

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

classes = ['human_faces', 'animals', 'vehicles']
class_counts = [84000, 25200, 58798]
total = sum(class_counts)
class_weights_array = [total / c for c in class_counts]

# Normalize weights
class_weights_array = class_weights_array / np.sum(class_weights_array)
class_weights_dict = {i: w for i, w in enumerate(class_weights_array)}

print("Class Weights for class_output:", class_weights_dict)
# Out:
# Class Weights for class_output: {0: np.float64(0.1735522553705624), 1: np.float64(0.5785075179018747), 2: np.float64(0.24794022672756288)}

# %%
import tensorflow.keras.backend as K
import tensorflow as tf

def weighted_categorical_crossentropy(weights):
    weights = tf.constant(weights, dtype=tf.float32)

    def loss(y_true, y_pred):
        y_pred = K.clip(y_pred, 1e-7, 1 - 1e-7)
        loss = -K.sum(y_true * K.log(y_pred) * weights, axis=-1)
        return loss

    return loss

# %%
loss_fn = weighted_categorical_crossentropy(list(class_weights_array))

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss={
        'label_output': 'binary_crossentropy',
        'class_output': loss_fn
    },
    metrics={
        'label_output': 'accuracy',
        'class_output': 'accuracy'
    }
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/deepfake_model.h5",  # you can change the name
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# %%
model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=3,
    steps_per_epoch=200,
    validation_steps=50,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/3
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - class_output_accuracy: 0.5159 - class_output_loss: 0.4767 - label_output_accuracy: 0.4872 - label_output_loss: 2.7784 - loss: 3.2552
# Epoch 1: val_loss improved from inf to 0.32605, saving model to /content/drive/MyDrive/deepfake_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 222s 894ms/step - class_output_accuracy: 0.5161 - class_output_loss: 0.4760 - label_output_accuracy: 0.4873 - label_output_loss: 2.7730 - loss: 3.2490 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 0.0135 - val_label_output_accuracy: 1.0000 - val_label_output_loss: 0.3125 - val_loss: 0.3260
# Epoch 2/3
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 892ms/step - class_output_accuracy: 0.7921 - class_output_loss: 0.1985 - label_output_accuracy: 0.5682 - label_output_loss: 0.6738 - loss: 0.8722
# Epoch 2: val_loss did not improve from 0.32605
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 184s 922ms/step - class_output_accuracy: 0.7923 - class_output_loss: 0.1984 - label_output_accuracy: 0.5683 - label_output_loss: 0.6737 - loss: 0.8721 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 0.0097 - val_label_output_accuracy: 0.9149 - val_label_output_loss: 0.4447 - val_loss: 0.4544
# Epoch 3/3
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 909ms/step - class_output_accuracy: 0.9348 - class_output_loss: 0.1408 - label_output_accuracy: 0.6555 - label_output_loss: 0.6388 - loss: 0.7797
# Epoch 3: val_loss did not improve from 0.32605
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 187s 935ms/step - class_output_accuracy: 0.9349 - class_output_loss: 0.1407 - label_output_accuracy: 0.6555 - label_output_loss: 0.6388 - loss: 0.7795 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 0.0037 - val_label_output_accuracy: 0.8785 - val_label_output_loss: 0.4878 - val_loss: 0.4916

# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import random

# Load your latest model
model = load_model("/content/drive/MyDrive/deepfake_model.h5")

# Update this if using Xception: (299, 299)
IMG_SIZE = (299, 299)  # Use (299, 299) if trained with Xception
test_dir = "/content/ArtiFact_240K/ArtiFact_240K/test"
class_names = ['human_faces', 'animals', 'vehicles']
results = []

# Get 5 random test images
test_images = [f for f in os.listdir(test_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
sample_images = random.sample(test_images, 200)  # Change number if needed

print(f"Testing {len(sample_images)} images...\n")

for idx, fname in enumerate(sample_images, 1):
    img_path = os.path.join(test_dir, fname)

    # Load and preprocess image
    img = load_img(img_path, target_size=IMG_SIZE)
    img_arr = img_to_array(img) / 255.0
    img_arr = np.expand_dims(img_arr, axis=0)

    # Predict
    label_pred, class_pred = model.predict(img_arr, verbose=0)
    label = int(label_pred[0][0] > 0.5)
    label_conf = float(label_pred[0][0])
    class_idx = np.argmax(class_pred[0])
    class_conf = float(class_pred[0][class_idx])
    class_name = class_names[class_idx]

    # Print prediction
    print(f"[{idx}] {fname} → Label: {'Real' if label else 'Fake'} ({label_conf:.2f}), "
          f"Class: {class_name} ({class_conf:.2f})")

    # Store result
    results.append([fname, label, class_name])

# Save to CSV
df = pd.DataFrame(results, columns=["image", "label", "class"])
df.to_csv("test_small.csv", index=False)

print("\n✅ test_small.csv saved.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Testing 200 images...
#
# [1] test_07310.jpg → Label: Real (0.52), Class: human_faces (0.77)
# [2] test_05246.jpg → Label: Real (0.57), Class: human_faces (0.40)
# [3] test_03605.jpg → Label: Real (0.66), Class: human_faces (0.88)
# [4] test_05512.jpg → Label: Real (0.51), Class: vehicles (0.35)
# [5] test_08454.jpg → Label: Real (0.88), Class: human_faces (0.98)
# [6] test_08881.jpg → Label: Real (0.76), Class: human_faces (0.95)
# [7] test_10653.jpg → Label: Real (0.51), Class: vehicles (0.36)
# [8] test_00933.jpg → Label: Real (0.90), Class: human_faces (0.98)
# [9] test_10333.jpg → Label: Real (0.54), Class: human_faces (0.37)
# [10] test_06487.jpg → Label: Real (0.60), Class: human_faces (0.44)
# [11] test_01330.jpg → Label: Real (0.66), Class: human_faces (0.89)
# [12] test_01681.jpg → Label: Real (0.71), Class: human_faces (0.89)
# [13] test_07182.jpg → Label: Real (0.58), Class: human_faces (0.80)
# [14] test_08363.jpg → Label: Real (0.76), Class: human_faces (0.95)
# [15] test_03416.jpg → Label: Real (0.66), Class: human_faces (0.90)
# [16] test_00134.jpg → Label: Real (0.53), Class: human_faces (0.36)
# [17] test_07027.jpg → Label: Real (0.55), Class: human_faces (0.84)
# [18] test_00375.jpg → Label: Real (0.54), Class: human_faces (0.38)
# [19] test_02619.jpg → Label: Real (0.70), Class: human_faces (0.91)
# [20] test_11513.jpg → Label: Real (0.60), Class: human_faces (0.47)
# [21] test_01539.jpg → Label: Real (0.61), Class: human_faces (0.82)
# [22] test_04518.jpg → Label: Real (0.52), Class: human_faces (0.37)
# [23] test_02607.jpg → Label: Real (0.86), Class: human_faces (0.97)
# [24] test_00995.jpg → Label: Real (0.74), Class: human_faces (0.88)
# [25] test_03874.jpg → Label: Real (0.84), Class: human_faces (0.97)
# [26] test_05585.jpg → Label: Real (0.52), Class: human_faces (0.39)
# [27] test_04556.jpg → Label: Real (0.56), Class: vehicles (0.36)
# [28] test_01239.jpg → Label: Real (0.74), Class: human_faces (0.93)
# [29] test_03250.jpg → Label: Real (0.73), Class: human_faces (0.91)
# [30] test_11873.jpg → Label: Real (0.50), Class: vehicles (0.37)
# [31] test_10567.jpg → Label: Real (0.54), Class: vehicles (0.36)
# [32] test_06366.jpg → Label: Real (0.51), Class: human_faces (0.38)
# [33] test_11713.jpg → Label: Real (0.51), Class: vehicles (0.37)
# [34] test_07057.jpg → Label: Real (0.69), Class: human_faces (0.93)
# [35] test_03910.jpg → Label: Real (0.58), Class: human_faces (0.37)
# [36] test_08376.jpg → Label: Real (0.57), Class: human_faces (0.81)
# [37] test_02187.jpg → Label: Real (0.77), Class: human_faces (0.95)
# [38] test_07571.jpg → Label: Real (0.53), Class: human_faces (0.79)
# [39] test_03972.jpg → Label: Real (0.59), Class: human_faces (0.40)
# [40] test_11421.jpg → Label: Real (0.51), Class: vehicles (0.37)
# [41] test_05907.jpg → Label: Real (0.54), Class: human_faces (0.35)
# [42] test_06877.jpg → Label: Real (0.56), Class: animals (0.39)
# [43] test_08458.jpg → Label: Real (0.65), Class: human_faces (0.84)
# [44] test_06231.jpg → Label: Real (0.56), Class: human_faces (0.38)
# [45] test_03711.jpg → Label: Real (0.59), Class: human_faces (0.84)
# [46] test_08761.jpg → Label: Real (0.52), Class: human_faces (0.71)
# [47] test_07532.jpg → Label: Real (0.51), Class: human_faces (0.49)
# [48] test_01345.jpg → Label: Real (0.82), Class: human_faces (0.97)
# [49] test_00708.jpg → Label: Real (0.53), Class: animals (0.37)
# [50] test_05087.jpg → Label: Real (0.56), Class: human_faces (0.49)
# [51] test_09865.jpg → Label: Real (0.57), Class: human_faces (0.74)
# [52] test_07329.jpg → Label: Real (0.76), Class: human_faces (0.95)
# [53] test_01258.jpg → Label: Real (0.74), Class: human_faces (0.94)
# [54] test_07242.jpg → Label: Real (0.62), Class: human_faces (0.86)
# [55] test_08612.jpg → Label: Real (0.52), Class: human_faces (0.71)
# [56] test_09767.jpg → Label: Real (0.61), Class: human_faces (0.85)
# [57] test_03434.jpg → Label: Real (0.83), Class: human_faces (0.97)
# [58] test_11772.jpg → Label: Real (0.54), Class: vehicles (0.37)
# [59] test_11970.jpg → Label: Real (0.56), Class: human_faces (0.39)
# [60] test_07964.jpg → Label: Real (0.55), Class: human_faces (0.78)
# [61] test_02825.jpg → Label: Real (0.66), Class: human_faces (0.91)
# [62] test_04171.jpg → Label: Real (0.57), Class: human_faces (0.52)
# [63] test_06043.jpg → Label: Real (0.54), Class: human_faces (0.38)
# [64] test_06196.jpg → Label: Real (0.59), Class: human_faces (0.41)
# [65] test_01928.jpg → Label: Real (0.85), Class: human_faces (0.98)
# [66] test_10753.jpg → Label: Real (0.52), Class: vehicles (0.37)
# [67] test_10712.jpg → Label: Real (0.63), Class: human_faces (0.58)
# [68] test_07410.jpg → Label: Real (0.55), Class: human_faces (0.76)
# [69] test_00904.jpg → Label: Real (0.73), Class: human_faces (0.94)
# [70] test_03094.jpg → Label: Real (0.81), Class: human_faces (0.96)
# [71] test_06923.jpg → Label: Real (0.84), Class: human_faces (0.98)
# [72] test_01452.jpg → Label: Real (0.71), Class: human_faces (0.95)
# [73] test_03560.jpg → Label: Real (0.77), Class: human_faces (0.96)
# [74] test_04208.jpg → Label: Real (0.62), Class: human_faces (0.70)
# [75] test_02306.jpg → Label: Real (0.79), Class: human_faces (0.96)
# [76] test_01359.jpg → Label: Real (0.61), Class: human_faces (0.84)
# [77] test_06605.jpg → Label: Real (0.61), Class: human_faces (0.38)
# [78] test_05683.jpg → Label: Real (0.52), Class: human_faces (0.35)
# [79] test_05789.jpg → Label: Real (0.53), Class: vehicles (0.37)
# [80] test_07695.jpg → Label: Real (0.72), Class: human_faces (0.94)
# [81] test_08259.jpg → Label: Real (0.55), Class: human_faces (0.77)
# [82] test_04822.jpg → Label: Real (0.57), Class: human_faces (0.39)
# [83] test_02451.jpg → Label: Real (0.73), Class: human_faces (0.85)
# [84] test_03244.jpg → Label: Real (0.80), Class: human_faces (0.96)
# [85] test_08684.jpg → Label: Real (0.84), Class: human_faces (0.97)
# [86] test_10614.jpg → Label: Real (0.52), Class: vehicles (0.35)
# [87] test_05946.jpg → Label: Real (0.53), Class: vehicles (0.36)
# [88] test_11485.jpg → Label: Real (0.51), Class: vehicles (0.37)
# [89] test_05681.jpg → Label: Real (0.55), Class: human_faces (0.36)
# [90] test_03750.jpg → Label: Real (0.84), Class: human_faces (0.97)
# [91] test_03601.jpg → Label: Real (0.75), Class: human_faces (0.95)
# [92] test_01542.jpg → Label: Real (0.56), Class: human_faces (0.81)
# [93] test_08859.jpg → Label: Real (0.79), Class: human_faces (0.97)
# [94] test_03488.jpg → Label: Real (0.74), Class: human_faces (0.94)
# [95] test_09271.jpg → Label: Real (0.51), Class: human_faces (0.71)
# [96] test_00036.jpg → Label: Real (0.55), Class: animals (0.39)
# [97] test_10931.jpg → Label: Real (0.51), Class: vehicles (0.36)
# [98] test_08302.jpg → Label: Real (0.90), Class: human_faces (0.99)
# [99] test_06388.jpg → Label: Real (0.56), Class: animals (0.42)
# [100] test_03716.jpg → Label: Real (0.78), Class: human_faces (0.95)
# [101] test_03341.jpg → Label: Real (0.80), Class: human_faces (0.97)
# [102] test_07285.jpg → Label: Real (0.77), Class: human_faces (0.86)
# [103] test_10910.jpg → Label: Real (0.51), Class: vehicles (0.36)
# [104] test_08488.jpg → Label: Real (0.52), Class: human_faces (0.66)
# [105] test_05524.jpg → Label: Real (0.51), Class: vehicles (0.37)
# [106] test_10647.jpg → Label: Real (0.51), Class: vehicles (0.36)
# [107] test_07151.jpg → Label: Real (0.62), Class: human_faces (0.85)
# [108] test_03869.jpg → Label: Real (0.64), Class: human_faces (0.86)
# [109] test_11176.jpg → Label: Fake (0.50), Class: vehicles (0.36)
# [110] test_00006.jpg → Label: Real (0.56), Class: animals (0.40)
# [111] test_08789.jpg → Label: Real (0.83), Class: human_faces (0.97)
# [112] test_02866.jpg → Label: Real (0.72), Class: human_faces (0.94)
# [113] test_00606.jpg → Label: Real (0.53), Class: human_faces (0.38)
# [114] test_11213.jpg → Label: Real (0.52), Class: vehicles (0.36)
# [115] test_06945.jpg → Label: Fake (0.50), Class: human_faces (0.70)
# [116] test_11575.jpg → Label: Real (0.59), Class: human_faces (0.40)
# [117] test_04271.jpg → Label: Real (0.57), Class: human_faces (0.40)
# [118] test_01680.jpg → Label: Real (0.55), Class: human_faces (0.81)
# [119] test_09419.jpg → Label: Real (0.57), Class: human_faces (0.78)
# [120] test_04522.jpg → Label: Real (0.54), Class: human_faces (0.39)
# [121] test_00542.jpg → Label: Real (0.56), Class: human_faces (0.36)
# [122] test_04830.jpg → Label: Real (0.55), Class: human_faces (0.39)
# [123] test_08972.jpg → Label: Real (0.71), Class: human_faces (0.90)
# [124] test_01508.jpg → Label: Real (0.63), Class: human_faces (0.87)
# [125] test_05935.jpg → Label: Real (0.55), Class: human_faces (0.40)
# [126] test_02984.jpg → Label: Real (0.69), Class: human_faces (0.91)
# [127] test_08433.jpg → Label: Real (0.61), Class: human_faces (0.88)
# [128] test_02427.jpg → Label: Real (0.83), Class: human_faces (0.98)
# [129] test_05753.jpg → Label: Real (0.51), Class: vehicles (0.35)
# [130] test_02910.jpg → Label: Real (0.81), Class: human_faces (0.97)
# [131] test_03822.jpg → Label: Real (0.82), Class: human_faces (0.98)
# [132] test_08999.jpg → Label: Real (0.70), Class: human_faces (0.85)
# [133] test_02146.jpg → Label: Real (0.70), Class: human_faces (0.94)
# [134] test_00070.jpg → Label: Real (0.57), Class: animals (0.43)
# [135] test_11616.jpg → Label: Real (0.53), Class: human_faces (0.36)
# [136] test_11198.jpg → Label: Real (0.53), Class: vehicles (0.36)
# [137] test_01401.jpg → Label: Real (0.82), Class: human_faces (0.97)
# [138] test_05006.jpg → Label: Real (0.63), Class: human_faces (0.57)
# [139] test_04077.jpg → Label: Real (0.53), Class: vehicles (0.37)
# [140] test_07948.jpg → Label: Real (0.70), Class: human_faces (0.90)
# [141] test_10967.jpg → Label: Real (0.51), Class: vehicles (0.37)
# [142] test_11140.jpg → Label: Real (0.56), Class: human_faces (0.42)
# [143] test_09068.jpg → Label: Real (0.71), Class: human_faces (0.92)
# [144] test_04689.jpg → Label: Real (0.51), Class: human_faces (0.37)
# [145] test_09172.jpg → Label: Real (0.50), Class: human_faces (0.59)
# [146] test_09962.jpg → Label: Real (0.57), Class: human_faces (0.36)
# [147] test_10602.jpg → Label: Real (0.62), Class: human_faces (0.48)
# [148] test_08157.jpg → Label: Real (0.53), Class: human_faces (0.72)
# [149] test_00869.jpg → Label: Real (0.53), Class: human_faces (0.40)
# [150] test_04205.jpg → Label: Real (0.54), Class: vehicles (0.39)
# [151] test_00596.jpg → Label: Real (0.56), Class: animals (0.42)
# [152] test_07265.jpg → Label: Real (0.65), Class: human_faces (0.87)
# [153] test_08514.jpg → Label: Real (0.51), Class: human_faces (0.77)
# [154] test_09360.jpg → Label: Real (0.86), Class: human_faces (0.98)
# [155] test_06648.jpg → Label: Real (0.55), Class: human_faces (0.36)
# [156] test_07363.jpg → Label: Real (0.62), Class: human_faces (0.87)
# [157] test_11311.jpg → Label: Real (0.66), Class: human_faces (0.63)
# [158] test_08647.jpg → Label: Real (0.66), Class: human_faces (0.92)
# [159] test_00650.jpg → Label: Real (0.53), Class: human_faces (0.38)
# [160] test_00735.jpg → Label: Real (0.55), Class: animals (0.36)
# [161] test_07237.jpg → Label: Real (0.78), Class: human_faces (0.96)
# [162] test_05820.jpg → Label: Real (0.54), Class: vehicles (0.37)
# [163] test_09819.jpg → Label: Real (0.69), Class: human_faces (0.91)
# [164] test_09557.jpg → Label: Real (0.68), Class: human_faces (0.86)
# [165] test_11503.jpg → Label: Real (0.53), Class: vehicles (0.38)
# [166] test_07481.jpg → Label: Real (0.82), Class: human_faces (0.96)
# [167] test_02762.jpg → Label: Real (0.72), Class: human_faces (0.91)
# [168] test_02976.jpg → Label: Real (0.89), Class: human_faces (0.99)
# [169] test_11502.jpg → Label: Real (0.60), Class: human_faces (0.39)
# [170] test_00514.jpg → Label: Real (0.54), Class: human_faces (0.44)
# [171] test_05372.jpg → Label: Real (0.52), Class: human_faces (0.36)
# [172] test_11464.jpg → Label: Real (0.54), Class: vehicles (0.36)
# [173] test_10513.jpg → Label: Real (0.53), Class: vehicles (0.37)
# [174] test_08532.jpg → Label: Real (0.53), Class: human_faces (0.62)
# [175] test_01234.jpg → Label: Real (0.87), Class: human_faces (0.98)
# [176] test_05286.jpg → Label: Real (0.52), Class: human_faces (0.40)
# [177] test_05010.jpg → Label: Real (0.62), Class: human_faces (0.45)
# [178] test_01008.jpg → Label: Real (0.71), Class: human_faces (0.94)
# [179] test_05025.jpg → Label: Real (0.51), Class: vehicles (0.36)
# [180] test_08710.jpg → Label: Real (0.83), Class: human_faces (0.97)
# [181] test_09016.jpg → Label: Real (0.91), Class: human_faces (0.99)
# [182] test_03053.jpg → Label: Real (0.71), Class: human_faces (0.87)
# [183] test_09318.jpg → Label: Real (0.73), Class: human_faces (0.92)
# [184] test_06857.jpg → Label: Real (0.53), Class: animals (0.38)
# [185] test_00261.jpg → Label: Real (0.55), Class: animals (0.39)
# [186] test_09058.jpg → Label: Real (0.53), Class: human_faces (0.67)
# [187] test_01321.jpg → Label: Real (0.74), Class: human_faces (0.95)
# [188] test_07400.jpg → Label: Real (0.50), Class: human_faces (0.68)
# [189] test_04679.jpg → Label: Real (0.58), Class: human_faces (0.42)
# [190] test_01615.jpg → Label: Real (0.88), Class: human_faces (0.98)
# [191] test_05745.jpg → Label: Real (0.52), Class: human_faces (0.34)
# [192] test_00455.jpg → Label: Real (0.53), Class: animals (0.36)
# [193] test_03163.jpg → Label: Real (0.74), Class: human_faces (0.92)
# [194] test_06737.jpg → Label: Real (0.55), Class: animals (0.42)
# [195] test_10259.jpg → Label: Real (0.51), Class: vehicles (0.37)
# [196] test_03182.jpg → Label: Real (0.82), Class: human_faces (0.95)
# [197] test_00490.jpg → Label: Real (0.54), Class: human_faces (0.44)
# [198] test_03551.jpg → Label: Real (0.67), Class: human_faces (0.88)
# [199] test_00371.jpg → Label: Real (0.56), Class: animals (0.41)
# [200] test_05996.jpg → Label: Real (0.52), Class: vehicles (0.37)
#
# ✅ test_small.csv saved.
